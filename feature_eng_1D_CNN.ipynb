# %%
import pandas as pd
from pprint import pprint

# %% [markdown]
# # RecordReader

# %%
import xarray as xr
import json
from typing import Union
from pathlib import Path
import glob



def to_path(p: Union[str, Path]) -> Path:
    return p if isinstance(p, Path) else Path(p)

def find_records(path: str):
    search_path: str = f"{path}/**/signals/"
    all_paths = list(map(lambda x: str(to_path(x).parent), glob.glob(search_path, recursive=True)))
    return all_paths

class RecordReader():
    def __init__(self, path: Union[str, Path]):
        self.path = to_path(path)

    def load_signal(self, sig_name):
        return xr.open_zarr(self.path / "signals" / sig_name / "dataset")

    def load_signal_meta(self, sig_name):
        with open(self.path / "signals" / sig_name / "meta.json", "r") as meta:
            return json.load(meta)
    
    def load_metadata(self):
        with open(self.path / "meta.json", "r") as meta:
            return json.load(meta)

    def load_crf_metadata(self):
        with open(self.path / "crf.json", "r") as meta:
            return json.load(meta)

# %%
records = find_records(("./"))

# %%
len(records)
# Out:
# 891

# %% [markdown]
# # Create a dataframes for signals and all data

# %%
data = {}
for r in records:
    reader = RecordReader(r)
    metadata = reader.load_metadata()
    scg_metadata = reader.load_signal_meta('scg-k')
    rsp_metadata = reader.load_signal_meta('rsp')
    crf_data = reader.load_crf_metadata()
    
    value = {
            'age': metadata['subject']['age']['value'],
            'sex' : metadata['subject']['sex'],
            'weight': metadata['subject']['weight']['value'],
            'height' : metadata['subject']['height']['value'],
            'subject_id' : crf_data['subject_id'],
            'study_id' : crf_data['study_id'],
            'hf_type' : crf_data['hf_type'],
            'sample_rate_scgk' : scg_metadata['sample_rate'],
            'nrg_lin_scgk' : reader.load_signal("scg-k").nrg.sel(motion="lin").to_pandas(),
            'nrg_rot_scgk' : reader.load_signal("scg-k").nrg.sel(motion="rot").to_pandas(),
            'pwr_lin_scgk': reader.load_signal("scg-k").pwr.sel(motion="lin").to_pandas(),
            'pwr_rot_scgk': reader.load_signal("scg-k").pwr.sel(motion="rot").to_pandas(),
            'sample_rate_rsp' : rsp_metadata['sample_rate'],
            'rsp': reader.load_signal("rsp").signal.to_pandas()
            }
    data[metadata['id']] = value

# %%
df = pd.DataFrame.from_dict(data, orient='index')

# %%
df.shape
# Out:
# (891, 14)

# %% [markdown]
# ## Generating time domain and wavelet features

# %%
import numpy as np
from scipy.stats import skew, kurtosis
import pywt

def calculate_features(ts):
    mean = np.mean(ts)
    std = np.std(ts)
    median = np.median(ts)
    minimum = np.min(ts)
    maximum = np.max(ts)
    skewness = skew(ts)
    kurt = kurtosis(ts)
    rms = np.sqrt(np.mean(np.square(ts)))
    zero_crossings = np.sum(np.diff(np.sign(ts)) != 0)
    
    # Wavelet transformation
    wavelet = 'sym4'
    coeffs = pywt.wavedec(ts, wavelet, level=4)
    
    # Calculate wavelet features
    wavelet_mean = np.mean(np.concatenate(coeffs))
    wavelet_std = np.std(np.concatenate(coeffs))
    wavelet_energy = np.sum(np.square(np.concatenate(coeffs)))
    
    return [mean, std, median, minimum, maximum, skewness, kurt, rms, zero_crossings, wavelet_mean, wavelet_std, wavelet_energy]

# Compute time series features for each subject
for subject_id, value in data.items():
    for feature in ['nrg_lin_scgk', 'nrg_rot_scgk', 'pwr_lin_scgk', 'pwr_rot_scgk', 'rsp']:
        ts = value[feature].values
        features = calculate_features(ts)
        
        # Store the computed features
        value[f"{feature}_mean"] = features[0]
        value[f"{feature}_std"] = features[1]
        value[f"{feature}_median"] = features[2]
        value[f"{feature}_min"] = features[3]
        value[f"{feature}_max"] = features[4]
        value[f"{feature}_skew"] = features[5]
        value[f"{feature}_kurt"] = features[6]
        value[f"{feature}_rms"] = features[7]
        value[f"{feature}_zero_crossings"] = features[8]
        value[f"{feature}_wavelet_mean"] = features[9]
        value[f"{feature}_wavelet_std"] = features[10]
        value[f"{feature}_wavelet_energy"] = features[11]

# Convert the dictionary to a DataFrame
df = pd.DataFrame.from_dict(data, orient='index')

# %%
df.dtypes
# Out:
# age                   float64
# sex                    object
# weight                float64
# height                float64
# subject_id             object
#                        ...
# rsp_rms               float64
# rsp_zero_crossings      int32
# rsp_wavelet_mean      float64
# rsp_wavelet_std       float64
# rsp_wavelet_energy    float64
# Length: 74, dtype: object

# %%
# Checking target
df.hf_type.value_counts()
# Out:
# NoHF       477
# UNKNOWN    282
# HFrEF       85
# HFpEF       27
# HFmEF       20
# Name: hf_type, dtype: int64

# %%
# Dropping the hf_type = UNKNOWN
df = df[df["hf_type"]!="UNKNOWN"]

# %%
# Check counts again
df.hf_type.value_counts()
# Out:
# NoHF     477
# HFrEF     85
# HFpEF     27
# HFmEF     20
# Name: hf_type, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
# Encode the hf_type column as integer labels
encoder = LabelEncoder()
df['hf_type'] = encoder.fit_transform(df['hf_type'])

# %%
# Check counts again
df.hf_type.value_counts()
# Out:
# 0    477
# 2     85
# 1     47
# Name: hf_type, dtype: int64

# %%
# Creating a function to code HFpEF and HFmEF into one category, NoHF second category, and HFrEF third
def convert(df):
    if df["hf_type"]==3:
        return 0
    elif df["hf_type"]==2:
        return 2
    else:
        return 1

# %%
df["hf_type"] = df.apply(lambda df: convert(df), axis=1)

# %% [markdown]
# ## Generating frequency features

# %%
from scipy.signal import periodogram
from scipy.stats import entropy

def spectral_entropy(pxx):
    psd_norm = pxx / np.sum(pxx)
    return entropy(psd_norm)

# Initialize a list to store the feature data
feature_data = []

# Iterate through the data dictionary
for key, value in data.items():
    # Calculate the periodogram for each time series
    freq_nrg_lin, pxx_nrg_lin = periodogram(value['nrg_lin_scgk'])
    freq_nrg_rot, pxx_nrg_rot = periodogram(value['nrg_rot_scgk'])
    freq_pwr_lin, pxx_pwr_lin = periodogram(value['pwr_lin_scgk'])
    freq_pwr_rot, pxx_pwr_rot = periodogram(value['pwr_rot_scgk'])
    freq_rsp, pxx_rsp = periodogram(value['rsp'])

    # Calculate the frequency-domain features for each time series
    features = {
        'record_id': key,
        'nrg_lin_mean_freq': np.mean(freq_nrg_lin),
        'nrg_lin_median_freq': np.median(freq_nrg_lin),
        'nrg_lin_peak_freq': freq_nrg_lin[np.argmax(pxx_nrg_lin)],
        'nrg_lin_spectral_entropy': spectral_entropy(pxx_nrg_lin),
        'nrg_rot_mean_freq': np.mean(freq_nrg_rot),
        'nrg_rot_median_freq': np.median(freq_nrg_rot),
        'nrg_rot_peak_freq': freq_nrg_rot[np.argmax(pxx_nrg_rot)],
        'nrg_rot_spectral_entropy': spectral_entropy(pxx_nrg_rot),
        'pwr_lin_mean_freq': np.mean(freq_pwr_lin),
        'pwr_lin_median_freq': np.median(freq_pwr_lin),
        'pwr_lin_peak_freq': freq_pwr_lin[np.argmax(pxx_pwr_lin)],
        'pwr_lin_spectral_entropy': spectral_entropy(pxx_pwr_lin),
        'pwr_rot_mean_freq': np.mean(freq_pwr_rot),
        'pwr_rot_median_freq': np.median(freq_pwr_rot),
        'pwr_rot_peak_freq': freq_pwr_rot[np.argmax(pxx_pwr_rot)],
        'pwr_rot_spectral_entropy': spectral_entropy(pxx_pwr_rot),
        'rsp_mean_freq': np.mean(freq_rsp),
        'rsp_median_freq': np.median(freq_rsp),
        'rsp_peak_freq': freq_rsp[np.argmax(pxx_rsp)],
        'rsp_spectral_entropy': spectral_entropy(pxx_rsp)
    }
    
    # Add the features to the feature_data list
    feature_data.append(features)

# Convert the feature_data list into a DataFrame
features_df = pd.DataFrame(feature_data)

# %%
features_df.head()
# Out:
#                                record_id  nrg_lin_mean_freq  \
# 0  Frontiers_CP-01_CP-01_20210413-000000               0.25
# 1  Frontiers_CP-02_CP-02_20210413-000000               0.25
# 2  Frontiers_CP-03_CP-03_20210413-000000               0.25
# 3  Frontiers_CP-04_CP-04_20210413-000000               0.25
# 4  Frontiers_CP-05_CP-05_20210414-000000               0.25
#
#    nrg_lin_median_freq  nrg_lin_peak_freq  nrg_lin_spectral_entropy  \
# 0                 0.25           0.002277                  7.382609
# 1                 0.25           0.002592                  7.718503
# 2                 0.25           0.000109                  7.214435
# 3                 0.25           0.000004                  8.455349
# 4                 0.25           0.000086                  7.870620
#
#    nrg_rot_mean_freq  nrg_rot_median_freq  nrg_rot_peak_freq  \
# 0               0.25                 0.25           0.002277
# 1               0.25                 0.25           0.002592
# 2               0.25                 0.25           0.000109
# 3               0.25                 0.25           0.000004
# 4               0.25                 0.25           0.000110
#
#    nrg_rot_spectral_entropy  pwr_lin_mean_freq  ...  pwr_lin_peak_freq  \
# 0                  8.348998               0.25  ...           0.025148
# 1                  9.763231               0.25  ...           0.023480
# 2                  8.674756               0.25  ...           0.023857
# 3                  9.045688               0.25  ...           0.028346
# 4                  7.873324               0.25  ...           0.022972
#
#    pwr_lin_spectral_entropy  pwr_rot_mean_freq  pwr_rot_median_freq  \
# 0                  9.213835               0.25                 0.25
# 1                  9.614558               0.25                 0.25
# 2                  8.361892               0.25                 0.25
# 3                 10.193032               0.25                 0.25
# 4                  8.613639               0.25                 0.25
#
#    pwr_rot_peak_freq  pwr_rot_spectral_entropy  rsp_mean_freq  \
# 0           0.040044                  9.879472           0.25
# 1           0.068769                 10.072020           0.25
# 2           0.033608                 10.041811           0.25
# 3           0.109253                 10.290044           0.25
# 4           0.071168                  9.647862           0.25
#
#    rsp_median_freq  rsp_peak_freq  rsp_spectral_entropy
# 0             0.25       0.000416              4.894895
# 1             0.25       0.000532              4.359918
# 2             0.25       0.000585              4.340069
# 3             0.25       0.000886              4.932395
# 4             0.25       0.000595              4.094955
#
# [5 rows x 21 columns]

# %%
# Set the index of features_df to be the record_id
features_df.set_index('record_id', inplace=True)

# Join the main DataFrame with the features_df
combined_df = pd.merge(df, features_df, left_index=True, right_index=True)

# %%
combined_df.head()
# Out:
#                                         age     sex  weight  height  \
# Frontiers_CP-07_CP-07_20210414-000000  63.0  Female    55.0    1.58
# Frontiers_CP-25_CP-25_20210429-000000  73.0    Male    80.0    1.70
# Frontiers_CP-26_CP-26_20210430-000000  72.0    Male    52.0    1.69
# Frontiers_CP-32_CP-32_20210505-000000  66.0  Female    69.5    1.55
# Frontiers_CP-67_CP-67_20210716-000000  66.0  Female    73.0    1.50
#
#                                       subject_id   study_id  hf_type  \
# Frontiers_CP-07_CP-07_20210414-000000      CP-07  Frontiers        2
# Frontiers_CP-25_CP-25_20210429-000000      CP-25  Frontiers        2
# Frontiers_CP-26_CP-26_20210430-000000      CP-26  Frontiers        2
# Frontiers_CP-32_CP-32_20210505-000000      CP-32  Frontiers        2
# Frontiers_CP-67_CP-67_20210716-000000      CP-67  Frontiers        2
#
#                                        sample_rate_scgk  \
# Frontiers_CP-07_CP-07_20210414-000000               500
# Frontiers_CP-25_CP-25_20210429-000000               500
# Frontiers_CP-26_CP-26_20210430-000000               500
# Frontiers_CP-32_CP-32_20210505-000000               500
# Frontiers_CP-67_CP-67_20210716-000000               500
#
#                                                                             nrg_lin_scgk  \
# Frontiers_CP-07_CP-07_20210414-000000  time
# 0         3.717964e-42
# 2         4.858295...
# Frontiers_CP-25_CP-25_20210429-000000  time
# 0         4.395396e-42
# 2         1.656699...
# Frontiers_CP-26_CP-26_20210430-000000  time
# 0         3.352892e-42
# 2         4.087231...
# Frontiers_CP-32_CP-32_20210505-000000  time
# 0         2.669942e-41
# 2         2.060657...
# Frontiers_CP-67_CP-67_20210716-000000  time
# 0         2.530986e-39
# 2         3.016467...
#
#                                                                             nrg_rot_scgk  \
# Frontiers_CP-07_CP-07_20210414-000000  time
# 0         1.322109e-21
# 2         3.038149...
# Frontiers_CP-25_CP-25_20210429-000000  time
# 0         3.101110e-21
# 2         4.808838...
# Frontiers_CP-26_CP-26_20210430-000000  time
# 0         7.375647e-21
# 2         6.487727...
# Frontiers_CP-32_CP-32_20210505-000000  time
# 0         1.168071e-20
# 2         1.303850...
# Frontiers_CP-67_CP-67_20210716-000000  time
# 0         1.358777e-18
# 2         2.192057...
#
#                                        ... pwr_lin_peak_freq  \
# Frontiers_CP-07_CP-07_20210414-000000  ...          0.031442
# Frontiers_CP-25_CP-25_20210429-000000  ...          0.022854
# Frontiers_CP-26_CP-26_20210430-000000  ...          0.027830
# Frontiers_CP-32_CP-32_20210505-000000  ...          0.019943
# Frontiers_CP-67_CP-67_20210716-000000  ...          0.019805
#
#                                       pwr_lin_spectral_entropy  \
# Frontiers_CP-07_CP-07_20210414-000000                 9.177957
# Frontiers_CP-25_CP-25_20210429-000000                 8.438479
# Frontiers_CP-26_CP-26_20210430-000000                 9.132068
# Frontiers_CP-32_CP-32_20210505-000000                 8.962660
# Frontiers_CP-67_CP-67_20210716-000000                 9.155824
#
#                                        pwr_rot_mean_freq pwr_rot_median_freq  \
# Frontiers_CP-07_CP-07_20210414-000000               0.25                0.25
# Frontiers_CP-25_CP-25_20210429-000000               0.25                0.25
# Frontiers_CP-26_CP-26_20210430-000000               0.25                0.25
# Frontiers_CP-32_CP-32_20210505-000000               0.25                0.25
# Frontiers_CP-67_CP-67_20210716-000000               0.25                0.25
#
#                                        pwr_rot_peak_freq  \
# Frontiers_CP-07_CP-07_20210414-000000           0.064219
# Frontiers_CP-25_CP-25_20210429-000000           0.022188
# Frontiers_CP-26_CP-26_20210430-000000           0.104303
# Frontiers_CP-32_CP-32_20210505-000000           0.112769
# Frontiers_CP-67_CP-67_20210716-000000           0.058725
#
#                                        pwr_rot_spectral_entropy  \
# Frontiers_CP-07_CP-07_20210414-000000                  9.810664
# Frontiers_CP-25_CP-25_20210429-000000                  9.724399
# Frontiers_CP-26_CP-26_20210430-000000                 10.346608
# Frontiers_CP-32_CP-32_20210505-000000                 10.078464
# Frontiers_CP-67_CP-67_20210716-000000                  9.725593
#
#                                        rsp_mean_freq  rsp_median_freq  \
# Frontiers_CP-07_CP-07_20210414-000000           0.25             0.25
# Frontiers_CP-25_CP-25_20210429-000000           0.25             0.25
# Frontiers_CP-26_CP-26_20210430-000000           0.25             0.25
# Frontiers_CP-32_CP-32_20210505-000000           0.25             0.25
# Frontiers_CP-67_CP-67_20210716-000000           0.25             0.25
#
#                                        rsp_peak_freq  rsp_spectral_entropy
# Frontiers_CP-07_CP-07_20210414-000000       0.000535              4.034055
# Frontiers_CP-25_CP-25_20210429-000000       0.000629              3.756682
# Frontiers_CP-26_CP-26_20210430-000000       0.000681              4.096104
# Frontiers_CP-32_CP-32_20210505-000000       0.000800              4.824584
# Frontiers_CP-67_CP-67_20210716-000000       0.000758              4.138203
#
# [5 rows x 94 columns]

# %%
combined_df.columns
# Out:
# Index(['age', 'sex', 'weight', 'height', 'subject_id', 'study_id', 'hf_type',
#        'sample_rate_scgk', 'nrg_lin_scgk', 'nrg_rot_scgk', 'pwr_lin_scgk',
#        'pwr_rot_scgk', 'sample_rate_rsp', 'rsp', 'nrg_lin_scgk_mean',
#        'nrg_lin_scgk_std', 'nrg_lin_scgk_median', 'nrg_lin_scgk_min',
#        'nrg_lin_scgk_max', 'nrg_lin_scgk_skew', 'nrg_lin_scgk_kurt',
#        'nrg_lin_scgk_rms', 'nrg_lin_scgk_zero_crossings',
#        'nrg_lin_scgk_wavelet_mean', 'nrg_lin_scgk_wavelet_std',
#        'nrg_lin_scgk_wavelet_energy', 'nrg_rot_scgk_mean', 'nrg_rot_scgk_std',
#        'nrg_rot_scgk_median', 'nrg_rot_scgk_min', 'nrg_rot_scgk_max',
#        'nrg_rot_scgk_skew', 'nrg_rot_scgk_kurt', 'nrg_rot_scgk_rms',
#        'nrg_rot_scgk_zero_crossings', 'nrg_rot_scgk_wavelet_mean',
#        'nrg_rot_scgk_wavelet_std', 'nrg_rot_scgk_wavelet_energy',
#        'pwr_lin_scgk_mean', 'pwr_lin_scgk_std', 'pwr_lin_scgk_median',
#        'pwr_lin_scgk_min', 'pwr_lin_scgk_max', 'pwr_lin_scgk_skew',
#        'pwr_lin_scgk_kurt', 'pwr_lin_scgk_rms', 'pwr_lin_scgk_zero_crossings',
#        'pwr_lin_scgk_wavelet_mean', 'pwr_lin_scgk_wavelet_std',
#        'pwr_lin_scgk_wavelet_energy', 'pwr_rot_scgk_mean', 'pwr_rot_scgk_std',
#        'pwr_rot_scgk_median', 'pwr_rot_scgk_min', 'pwr_rot_scgk_max',
#        'pwr_rot_scgk_skew', 'pwr_rot_scgk_kurt', 'pwr_rot_scgk_rms',
#        'pwr_rot_scgk_zero_crossings', 'pwr_rot_scgk_wavelet_mean',
#        'pwr_rot_scgk_wavelet_std', 'pwr_rot_scgk_wavelet_energy', 'rsp_mean',
#        'rsp_std', 'rsp_median', 'rsp_min', 'rsp_max', 'rsp_skew', 'rsp_kurt',
#        'rsp_rms', 'rsp_zero_crossings', 'rsp_wavelet_mean', 'rsp_wavelet_std',
#        'rsp_wavelet_energy', 'nrg_lin_mean_freq', 'nrg_lin_median_freq',
#        'nrg_lin_peak_freq', 'nrg_lin_spectral_entropy', 'nrg_rot_mean_freq',
#        'nrg_rot_median_freq', 'nrg_rot_peak_freq', 'nrg_rot_spectral_entropy',
#        'pwr_lin_mean_freq', 'pwr_lin_median_freq', 'pwr_lin_peak_freq',
#        'pwr_lin_spectral_entropy', 'pwr_rot_mean_freq', 'pwr_rot_median_freq',
#        'pwr_rot_peak_freq', 'pwr_rot_spectral_entropy', 'rsp_mean_freq',
#        'rsp_median_freq', 'rsp_peak_freq', 'rsp_spectral_entropy'],
#       dtype='object')

# %% [markdown]
# ## Modelling

# %% [markdown]
# First is just sample code (Random forest is used without any preproccesing just to see if code is functional)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import GroupShuffleSplit
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, roc_auc_score

# Encode the 'sex' column
#combined_df['sex'] = combined_df['sex'].map({'M': 0, 'F': 1})



# Drop the original columns containing DataFrames
# Split the dataset into features (X) and target (y)
X = combined_df.drop(['hf_type', 'study_id', 'subject_id', 'sex', 'nrg_lin_scgk', 'nrg_rot_scgk', 'pwr_lin_scgk', 'pwr_rot_scgk', 'rsp'], axis=1)
y = combined_df['hf_type']

# Extract subject_id as groups
groups = combined_df['subject_id']

# Initialize the GroupShuffleSplit
gss = GroupShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

# Get the train and test indices based on the groups
train_idx, test_idx = next(gss.split(X, y, groups))

# Split the dataset into training and testing sets
X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

# Initialize the classifier
clf = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the classifier
clf.fit(X_train, y_train)

# Make predictions on the test set
y_pred = clf.predict(X_test)

# Evaluate the classifier
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# ROC auc
roc_auc = roc_auc_score(y_test, clf.predict_proba(X_test), multi_class="ovr", average="macro")
print(f"Macro-averaged One-vs-Rest ROC AUC score:\n{roc_auc}")
# Out:
# Accuracy: 0.9029850746268657
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95       112
#            1       0.50      0.29      0.36         7
#            2       0.90      0.60      0.72        15
#
#     accuracy                           0.90       134
#    macro avg       0.77      0.62      0.68       134
# weighted avg       0.89      0.90      0.89       134
#
# Macro-averaged One-vs-Rest ROC AUC score:
# 0.9564889428092879

# %% [markdown]
# XBG

# %%
import xgboost as xgb
from sklearn.model_selection import GroupShuffleSplit
from sklearn.metrics import classification_report, accuracy_score, roc_auc_score

# Split the dataset into features (X) and target (y)
X = combined_df.drop(['hf_type', 'study_id', 'subject_id', 'sex', 'nrg_lin_scgk', 'nrg_rot_scgk', 'pwr_lin_scgk', 'pwr_rot_scgk', 'rsp'], axis=1)
y = combined_df['hf_type']

# Extract subject_id as groups
groups = combined_df['subject_id']

# Initialize the GroupShuffleSplit
gss = GroupShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

# Get the train and test indices based on the groups
train_idx, test_idx = next(gss.split(X, y, groups))

# Split the dataset into training and testing sets
X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

# Determine the number of unique classes in the target variable
num_classes = y.nunique()

# Initialize the classifier
clf = xgb.XGBClassifier(
    objective='multi:softproba',
    num_class=num_classes,
    n_estimators=100,
    random_state=42,
    use_label_encoder=False,
)

# Train the classifier
clf.fit(X_train, y_train, eval_metric='mlogloss')

# Make predictions on the test set
y_pred = clf.predict(X_test)

# Evaluate the classifier
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# ROC auc
roc_auc = roc_auc_score(y_test, clf.predict_proba(X_test), multi_class="ovr", average="macro")
print(f"Macro-averaged One-vs-Rest ROC AUC score:\n{roc_auc}")
# Out:
# F:\conda\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# Accuracy: 0.9328358208955224
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97       112
#            1       0.60      0.43      0.50         7
#            2       0.86      0.80      0.83        15
#
#     accuracy                           0.93       134
#    macro avg       0.80      0.74      0.77       134
# weighted avg       0.93      0.93      0.93       134
#
# Macro-averaged One-vs-Rest ROC AUC score:
# 0.9496778519329468

# %% [markdown]
# ## 1D CNN

# %%
from sklearn.model_selection import GroupShuffleSplit
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report, accuracy_score, roc_auc_score, recall_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, BatchNormalization, MaxPooling1D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical

# Split the dataset into features (X) and target (y)
X = combined_df.drop(['hf_type', 'study_id', 'subject_id', 'sex', 'nrg_lin_scgk', 'nrg_rot_scgk', 'pwr_lin_scgk', 'pwr_rot_scgk', 'rsp'], axis=1)
y = combined_df['hf_type']

# Extract subject_id as groups
groups = combined_df['subject_id']

# Initialize the GroupShuffleSplit
gss = GroupShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

# Get the train and test indices based on the groups
train_idx, test_idx = next(gss.split(X, y, groups))

# Split the dataset into training and testing sets
X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

# Standardize the input features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# One-hot encode the target variable
#encoder = LabelEncoder()
#y_train_enc = encoder.fit_transform(y_train)
#y_test_enc = encoder.transform(y_test)
y_train_cat = to_categorical(y_train_enc)
y_test_cat = to_categorical(y_test_enc)

# Reshape the input features to fit the 1D CNN model
max_length = X_train.shape[1]
X_train = X_train.reshape((X_train.shape[0], max_length, 1))
X_test = X_test.reshape((X_test.shape[0], max_length, 1))

# Define the model architecture
model = Sequential()

# Add the first convolutional block
model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(max_length, 1)))
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=2))

# Add the second convolutional block
model.add(Conv1D(filters=16, kernel_size=3, activation='relu'))
model.add(Dropout(rate=0.5))
model.add(MaxPooling1D(pool_size=2))

# Add the third convolutional block
model.add(Conv1D(filters=16, kernel_size=3, activation='relu'))
model.add(Dropout(rate=0.5))

# Flatten the output of the convolutional blocks
model.add(Flatten())

# Add the fully connected layers
model.add(Dense(units=1000, activation='relu'))
model.add(Dropout(rate=0.5))
model.add(Dense(units=1000, activation='relu'))
model.add(Dropout(rate=0.5))

# Add the output layer with Softmax activation function
model.add(Dense(units=3, activation='softmax'))

# Define the early stopping callback
early_stopping = EarlyStopping(patience=10, monitor='val_loss', mode='min', verbose=1, restore_best_weights=True)

# Compile the model with categorical crossentropy loss
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model on the combined time series data
model.fit(X_train, y_train_cat, epochs=100, validation_data=(X_test, y_test_cat), callbacks=[early_stopping])


# Evaluate the model on the test set
y_pred_cat = model.predict(X_test)
y_pred = np.argmax(y_pred_cat, axis=1)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")

# Compute recall
recall = recall_score(y_test, y_pred, average=None)
print(f"Recall: {recall}")

# ROC auc
roc_auc = roc_auc_score(y_test, y_pred_cat, multi_class="ovr", average="macro")
print(f"Macro-averaged One-vs-Rest ROC AUC score:\n{roc_auc}")
# Out:
# Epoch 1/100
# 15/15 [==============================] - 3s 45ms/step - loss: 0.9977 - accuracy: 0.7053 - val_loss: 1.0683 - val_accuracy: 0.7687
# Epoch 2/100
# 15/15 [==============================] - 0s 26ms/step - loss: 0.7571 - accuracy: 0.7389 - val_loss: 1.0079 - val_accuracy: 0.8433
# Epoch 3/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.6941 - accuracy: 0.7368 - val_loss: 0.9799 - val_accuracy: 0.8433
# Epoch 4/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.6549 - accuracy: 0.7621 - val_loss: 0.9578 - val_accuracy: 0.8433
# Epoch 5/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.6050 - accuracy: 0.7389 - val_loss: 0.9135 - val_accuracy: 0.8433
# Epoch 6/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.6230 - accuracy: 0.7684 - val_loss: 0.8655 - val_accuracy: 0.8433
# Epoch 7/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.6170 - accuracy: 0.7747 - val_loss: 0.8664 - val_accuracy: 0.8433
# Epoch 8/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.6218 - accuracy: 0.7705 - val_loss: 0.8763 - val_accuracy: 0.8433
# Epoch 9/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.5891 - accuracy: 0.7663 - val_loss: 0.8236 - val_accuracy: 0.8433
# Epoch 10/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.5728 - accuracy: 0.7726 - val_loss: 0.7822 - val_accuracy: 0.8433
# Epoch 11/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.5956 - accuracy: 0.7726 - val_loss: 0.7548 - val_accuracy: 0.8433
# Epoch 12/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.5244 - accuracy: 0.7958 - val_loss: 0.6952 - val_accuracy: 0.8433
# Epoch 13/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.5206 - accuracy: 0.7853 - val_loss: 0.6546 - val_accuracy: 0.8433
# Epoch 14/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.5663 - accuracy: 0.7789 - val_loss: 0.6193 - val_accuracy: 0.8507
# Epoch 15/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.5307 - accuracy: 0.7811 - val_loss: 0.6050 - val_accuracy: 0.8507
# Epoch 16/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.5195 - accuracy: 0.7916 - val_loss: 0.5665 - val_accuracy: 0.8507
# Epoch 17/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.4988 - accuracy: 0.8063 - val_loss: 0.5511 - val_accuracy: 0.8507
# Epoch 18/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.5021 - accuracy: 0.7853 - val_loss: 0.5024 - val_accuracy: 0.8582
# Epoch 19/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.4941 - accuracy: 0.8021 - val_loss: 0.4623 - val_accuracy: 0.8507
# Epoch 20/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.5217 - accuracy: 0.7705 - val_loss: 0.5063 - val_accuracy: 0.8433
# Epoch 21/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.5220 - accuracy: 0.7958 - val_loss: 0.4857 - val_accuracy: 0.8507
# Epoch 22/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.5104 - accuracy: 0.8000 - val_loss: 0.4261 - val_accuracy: 0.8507
# Epoch 23/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.4582 - accuracy: 0.7916 - val_loss: 0.4036 - val_accuracy: 0.8433
# Epoch 24/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.4807 - accuracy: 0.8021 - val_loss: 0.3984 - val_accuracy: 0.8582
# Epoch 25/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.5230 - accuracy: 0.7811 - val_loss: 0.3983 - val_accuracy: 0.8507
# Epoch 26/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.5248 - accuracy: 0.7895 - val_loss: 0.4166 - val_accuracy: 0.8731
# Epoch 27/100
# 15/15 [==============================] - 0s 25ms/step - loss: 0.5038 - accuracy: 0.7874 - val_loss: 0.3570 - val_accuracy: 0.8433
# Epoch 28/100
# 15/15 [==============================] - 0s 25ms/step - loss: 0.4944 - accuracy: 0.7979 - val_loss: 0.3520 - val_accuracy: 0.8507
# Epoch 29/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.4803 - accuracy: 0.7832 - val_loss: 0.3455 - val_accuracy: 0.8881
# Epoch 30/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.4678 - accuracy: 0.8000 - val_loss: 0.3195 - val_accuracy: 0.8806
# Epoch 31/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.4379 - accuracy: 0.8021 - val_loss: 0.3064 - val_accuracy: 0.8806
# Epoch 32/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.4629 - accuracy: 0.8084 - val_loss: 0.3114 - val_accuracy: 0.8806
# Epoch 33/100
# 15/15 [==============================] - 0s 25ms/step - loss: 0.4273 - accuracy: 0.8211 - val_loss: 0.3005 - val_accuracy: 0.8806
# Epoch 34/100
# 15/15 [==============================] - 0s 25ms/step - loss: 0.4347 - accuracy: 0.8295 - val_loss: 0.2998 - val_accuracy: 0.9179
# Epoch 35/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.4491 - accuracy: 0.7979 - val_loss: 0.2845 - val_accuracy: 0.9104
# Epoch 36/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.4583 - accuracy: 0.8211 - val_loss: 0.2972 - val_accuracy: 0.8955
# Epoch 37/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.4980 - accuracy: 0.8000 - val_loss: 0.3007 - val_accuracy: 0.8731
# Epoch 38/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.4726 - accuracy: 0.8147 - val_loss: 0.3045 - val_accuracy: 0.8955
# Epoch 39/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.4475 - accuracy: 0.8147 - val_loss: 0.2925 - val_accuracy: 0.8881
# Epoch 40/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.4590 - accuracy: 0.7937 - val_loss: 0.2955 - val_accuracy: 0.9254
# Epoch 41/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.4659 - accuracy: 0.7895 - val_loss: 0.2910 - val_accuracy: 0.8657
# Epoch 42/100
# 15/15 [==============================] - 0s 25ms/step - loss: 0.4386 - accuracy: 0.8189 - val_loss: 0.2945 - val_accuracy: 0.9030
# Epoch 43/100
# 15/15 [==============================] - 0s 25ms/step - loss: 0.4502 - accuracy: 0.8211 - val_loss: 0.2799 - val_accuracy: 0.8806
# Epoch 44/100
# 15/15 [==============================] - 0s 25ms/step - loss: 0.4196 - accuracy: 0.8105 - val_loss: 0.2741 - val_accuracy: 0.9179
# Epoch 45/100
# 15/15 [==============================] - 0s 25ms/step - loss: 0.4189 - accuracy: 0.8189 - val_loss: 0.2829 - val_accuracy: 0.9030
# Epoch 46/100
# 15/15 [==============================] - 0s 27ms/step - loss: 0.4265 - accuracy: 0.8084 - val_loss: 0.2585 - val_accuracy: 0.9104
# Epoch 47/100
# 15/15 [==============================] - 0s 25ms/step - loss: 0.4285 - accuracy: 0.8253 - val_loss: 0.2486 - val_accuracy: 0.9179
# Epoch 48/100
# 15/15 [==============================] - 0s 26ms/step - loss: 0.4244 - accuracy: 0.8147 - val_loss: 0.2883 - val_accuracy: 0.8955
# Epoch 49/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.4515 - accuracy: 0.8147 - val_loss: 0.2681 - val_accuracy: 0.9104
# Epoch 50/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.4185 - accuracy: 0.8105 - val_loss: 0.2684 - val_accuracy: 0.9030
# Epoch 51/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.4369 - accuracy: 0.8295 - val_loss: 0.2557 - val_accuracy: 0.9030
# Epoch 52/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.4187 - accuracy: 0.8189 - val_loss: 0.2697 - val_accuracy: 0.9030
# Epoch 53/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.4402 - accuracy: 0.8084 - val_loss: 0.2611 - val_accuracy: 0.9104
# Epoch 54/100
# 15/15 [==============================] - 0s 25ms/step - loss: 0.4411 - accuracy: 0.8126 - val_loss: 0.2621 - val_accuracy: 0.8955
# Epoch 55/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.4147 - accuracy: 0.8316 - val_loss: 0.2752 - val_accuracy: 0.8955
# Epoch 56/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.4181 - accuracy: 0.8337 - val_loss: 0.2788 - val_accuracy: 0.9030
# Epoch 57/100
# 13/15 [=========================>....] - ETA: 0s - loss: 0.4413 - accuracy: 0.8341Restoring model weights from the end of the best epoch: 47.
# 15/15 [==============================] - 0s 24ms/step - loss: 0.4301 - accuracy: 0.8358 - val_loss: 0.2509 - val_accuracy: 0.9104
# Epoch 57: early stopping
# 5/5 [==============================] - 0s 4ms/step
# Accuracy: 0.917910447761194
# Recall: [0.97321429 0.42857143 0.73333333]
# Macro-averaged One-vs-Rest ROC AUC score:
# 0.9667861328497039

# %% [markdown]
# ## 5-fold CV

# %%
import numpy as np
from sklearn.model_selection import KFold
from sklearn.model_selection import GroupKFold


num_classes = y_train.nunique()
num_folds = 5

# One-hot encode the target variables
y_cat = to_categorical(y)

# Define a function to create and return the model
def create_model():

    # Define the model architecture
    model = Sequential()

    # Add the first convolutional block
    model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(max_length, 1)))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))

    # Add the second convolutional block
    model.add(Conv1D(filters=16, kernel_size=3, activation='relu'))
    model.add(Dropout(rate=0.5))
    model.add(MaxPooling1D(pool_size=2))

    # Add the third convolutional block
    model.add(Conv1D(filters=16, kernel_size=3, activation='relu'))
    model.add(Dropout(rate=0.5))

    # Flatten the output of the convolutional blocks
    model.add(Flatten())

    # Add the fully connected layers
    model.add(Dense(units=1000, activation='relu'))
    model.add(Dropout(rate=0.5))
    model.add(Dense(units=1000, activation='relu'))
    model.add(Dropout(rate=0.5))

    # Add the output layer with Softmax activation function
    model.add(Dense(units=3, activation='softmax'))

    # Compile the model with categorical crossentropy loss
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
              
    return model

# Initialize the GroupKFold cross-validator
num_folds = 5
group_kfold = GroupKFold(n_splits=num_folds)

# Initialize variables to store evaluation metrics
accuracies = []
recalls = []
roc_aucs = []

# Iterate through the folds
for train_idx, val_idx in group_kfold.split(X, y, groups):
    # Split the dataset into training and validation sets for the current fold
    X_train_fold, X_val_fold = X.iloc[train_idx], X.iloc[val_idx]
    y_train_fold, y_val_fold = y.iloc[train_idx], y.iloc[val_idx]

    # Standardize the input features
    scaler = StandardScaler()
    X_train_fold = scaler.fit_transform(X_train_fold)
    X_val_fold = scaler.transform(X_val_fold)

    # One-hot encode the target variable
    #y_train_fold_enc = encoder.transform(y_train_fold)
    #y_val_fold_enc = encoder.transform(y_val_fold)
    y_train_fold_cat = to_categorical(y_train_fold)
    y_val_fold_cat = to_categorical(y_val_fold)

    # Reshape the input features to fit the 1D CNN model
    X_train_fold = X_train_fold.reshape((X_train_fold.shape[0], max_length, 1))
    X_val_fold = X_val_fold.reshape((X_val_fold.shape[0], max_length, 1))

    # Create a new model for each fold
    model = create_model()

    # Train the model on the current fold
    model.fit(X_train_fold, y_train_fold_cat, epochs=100, validation_data=(X_val_fold, y_val_fold_cat), callbacks=[early_stopping], verbose=2)

    # Evaluate the model on the validation set
    y_pred_cat = model.predict(X_val_fold)
    y_pred = np.argmax(y_pred_cat, axis=1)
    accuracy = accuracy_score(y_val_fold, y_pred)
    accuracies.append(accuracy)

    recall = recall_score(y_val_fold, y_pred, average=None)
    recalls.append(recall)

    roc_auc = roc_auc_score(y_val_fold_cat, y_pred_cat, multi_class="ovr", average="macro")
    roc_aucs.append(roc_auc)

# Calculate and print mean and standard deviation of evaluation metrics
mean_accuracy = np.mean(accuracies)
std_accuracy = np.std(accuracies)
mean_recall = np.mean(recalls, axis=0)
std_recall = np.std(recalls, axis=0)
mean_roc_auc = np.mean(roc_aucs)
std_roc_auc = np.std(roc_aucs)

print(f"\nMean accuracy: {mean_accuracy:.4f}, Standard deviation: {std_accuracy:.4f}")
print(f"\nMean recall: {mean_recall}, Standard deviation: {std_recall}")
print(f"\nMean ROC AUC: {mean_roc_auc:.4f}, Standard deviation: {std_roc_auc:.4f}")
# Out:
# Epoch 1/100
# 16/16 - 3s - loss: 1.5073 - accuracy: 0.6838 - val_loss: 1.0085 - val_accuracy: 0.7869 - 3s/epoch - 181ms/step
# Epoch 2/100
# 16/16 - 0s - loss: 0.7795 - accuracy: 0.7577 - val_loss: 0.9809 - val_accuracy: 0.8033 - 376ms/epoch - 24ms/step
# Epoch 3/100
# 16/16 - 0s - loss: 0.6818 - accuracy: 0.7515 - val_loss: 0.9506 - val_accuracy: 0.8279 - 365ms/epoch - 23ms/step
# Epoch 4/100
# 16/16 - 0s - loss: 0.6374 - accuracy: 0.7885 - val_loss: 0.9304 - val_accuracy: 0.8279 - 354ms/epoch - 22ms/step
# Epoch 5/100
# 16/16 - 0s - loss: 0.5503 - accuracy: 0.7885 - val_loss: 0.9090 - val_accuracy: 0.8279 - 374ms/epoch - 23ms/step
# Epoch 6/100
# 16/16 - 0s - loss: 0.6059 - accuracy: 0.7618 - val_loss: 0.7831 - val_accuracy: 0.8033 - 385ms/epoch - 24ms/step
# Epoch 7/100
# 16/16 - 0s - loss: 0.5796 - accuracy: 0.7762 - val_loss: 0.8355 - val_accuracy: 0.8279 - 380ms/epoch - 24ms/step
# Epoch 8/100
# 16/16 - 0s - loss: 0.5975 - accuracy: 0.7762 - val_loss: 0.8063 - val_accuracy: 0.8033 - 371ms/epoch - 23ms/step
# Epoch 9/100
# 16/16 - 0s - loss: 0.5256 - accuracy: 0.7844 - val_loss: 0.7597 - val_accuracy: 0.8033 - 372ms/epoch - 23ms/step
# Epoch 10/100
# 16/16 - 0s - loss: 0.5664 - accuracy: 0.7762 - val_loss: 0.7321 - val_accuracy: 0.8115 - 377ms/epoch - 24ms/step
# Epoch 11/100
# 16/16 - 0s - loss: 0.5467 - accuracy: 0.7844 - val_loss: 0.7059 - val_accuracy: 0.8033 - 382ms/epoch - 24ms/step
# Epoch 12/100
# 16/16 - 0s - loss: 0.5210 - accuracy: 0.7967 - val_loss: 0.6253 - val_accuracy: 0.8033 - 375ms/epoch - 23ms/step
# Epoch 13/100
# 16/16 - 0s - loss: 0.4981 - accuracy: 0.7885 - val_loss: 0.6028 - val_accuracy: 0.8115 - 416ms/epoch - 26ms/step
# Epoch 14/100
# 16/16 - 0s - loss: 0.4716 - accuracy: 0.8193 - val_loss: 0.5531 - val_accuracy: 0.8033 - 395ms/epoch - 25ms/step
# Epoch 15/100
# 16/16 - 0s - loss: 0.4654 - accuracy: 0.8152 - val_loss: 0.5246 - val_accuracy: 0.8115 - 378ms/epoch - 24ms/step
# Epoch 16/100
# 16/16 - 0s - loss: 0.5084 - accuracy: 0.7947 - val_loss: 0.5580 - val_accuracy: 0.8197 - 382ms/epoch - 24ms/step
# Epoch 17/100
# 16/16 - 0s - loss: 0.4922 - accuracy: 0.7823 - val_loss: 0.5029 - val_accuracy: 0.8033 - 395ms/epoch - 25ms/step
# Epoch 18/100
# 16/16 - 0s - loss: 0.4658 - accuracy: 0.8008 - val_loss: 0.4931 - val_accuracy: 0.8197 - 382ms/epoch - 24ms/step
# Epoch 19/100
# 16/16 - 0s - loss: 0.4790 - accuracy: 0.8008 - val_loss: 0.4985 - val_accuracy: 0.8361 - 349ms/epoch - 22ms/step
# Epoch 20/100
# 16/16 - 0s - loss: 0.4601 - accuracy: 0.8029 - val_loss: 0.4805 - val_accuracy: 0.8279 - 354ms/epoch - 22ms/step
# Epoch 21/100
# 16/16 - 0s - loss: 0.4912 - accuracy: 0.8049 - val_loss: 0.4769 - val_accuracy: 0.8443 - 370ms/epoch - 23ms/step
# Epoch 22/100
# 16/16 - 0s - loss: 0.4759 - accuracy: 0.8234 - val_loss: 0.4903 - val_accuracy: 0.8361 - 375ms/epoch - 23ms/step
# Epoch 23/100
# 16/16 - 0s - loss: 0.4747 - accuracy: 0.8111 - val_loss: 0.4513 - val_accuracy: 0.8279 - 417ms/epoch - 26ms/step
# Epoch 24/100
# 16/16 - 0s - loss: 0.4313 - accuracy: 0.8214 - val_loss: 0.4324 - val_accuracy: 0.8443 - 372ms/epoch - 23ms/step
# Epoch 25/100
# 16/16 - 0s - loss: 0.4872 - accuracy: 0.7926 - val_loss: 0.4518 - val_accuracy: 0.8525 - 364ms/epoch - 23ms/step
# Epoch 26/100
# 16/16 - 0s - loss: 0.4228 - accuracy: 0.8214 - val_loss: 0.4313 - val_accuracy: 0.8361 - 369ms/epoch - 23ms/step
# Epoch 27/100
# 16/16 - 0s - loss: 0.4074 - accuracy: 0.8152 - val_loss: 0.4198 - val_accuracy: 0.8443 - 376ms/epoch - 23ms/step
# Epoch 28/100
# 16/16 - 0s - loss: 0.4484 - accuracy: 0.8214 - val_loss: 0.4278 - val_accuracy: 0.8197 - 362ms/epoch - 23ms/step
# Epoch 29/100
# 16/16 - 0s - loss: 0.4462 - accuracy: 0.8172 - val_loss: 0.4373 - val_accuracy: 0.8033 - 401ms/epoch - 25ms/step
# Epoch 30/100
# 16/16 - 0s - loss: 0.4340 - accuracy: 0.8090 - val_loss: 0.4324 - val_accuracy: 0.8197 - 427ms/epoch - 27ms/step
# Epoch 31/100
# 16/16 - 0s - loss: 0.4011 - accuracy: 0.8378 - val_loss: 0.4468 - val_accuracy: 0.8361 - 483ms/epoch - 30ms/step
# Epoch 32/100
# 16/16 - 0s - loss: 0.4164 - accuracy: 0.8255 - val_loss: 0.4485 - val_accuracy: 0.8443 - 471ms/epoch - 29ms/step
# Epoch 33/100
# 16/16 - 0s - loss: 0.4484 - accuracy: 0.8152 - val_loss: 0.4662 - val_accuracy: 0.8361 - 450ms/epoch - 28ms/step
# Epoch 34/100
# 16/16 - 0s - loss: 0.4077 - accuracy: 0.8337 - val_loss: 0.4582 - val_accuracy: 0.8361 - 351ms/epoch - 22ms/step
# Epoch 35/100
# 16/16 - 0s - loss: 0.4428 - accuracy: 0.8357 - val_loss: 0.4495 - val_accuracy: 0.8197 - 343ms/epoch - 21ms/step
# Epoch 36/100
# 16/16 - 0s - loss: 0.4190 - accuracy: 0.8172 - val_loss: 0.4595 - val_accuracy: 0.8279 - 348ms/epoch - 22ms/step
# Epoch 37/100
# Restoring model weights from the end of the best epoch: 27.
# 16/16 - 0s - loss: 0.4225 - accuracy: 0.8357 - val_loss: 0.4575 - val_accuracy: 0.8197 - 367ms/epoch - 23ms/step
# Epoch 37: early stopping
# 4/4 [==============================] - 0s 5ms/step
# Epoch 1/100
# 16/16 - 3s - loss: 1.2879 - accuracy: 0.7166 - val_loss: 1.0416 - val_accuracy: 0.7951 - 3s/epoch - 163ms/step
# Epoch 2/100
# 16/16 - 0s - loss: 0.7156 - accuracy: 0.7556 - val_loss: 1.0040 - val_accuracy: 0.7951 - 373ms/epoch - 23ms/step
# Epoch 3/100
# 16/16 - 0s - loss: 0.7094 - accuracy: 0.7864 - val_loss: 0.9913 - val_accuracy: 0.7869 - 356ms/epoch - 22ms/step
# Epoch 4/100
# 16/16 - 0s - loss: 0.6573 - accuracy: 0.7639 - val_loss: 0.9364 - val_accuracy: 0.7869 - 370ms/epoch - 23ms/step
# Epoch 5/100
# 16/16 - 0s - loss: 0.6225 - accuracy: 0.7536 - val_loss: 0.9074 - val_accuracy: 0.7869 - 351ms/epoch - 22ms/step
# Epoch 6/100
# 16/16 - 0s - loss: 0.6060 - accuracy: 0.7844 - val_loss: 0.8494 - val_accuracy: 0.7869 - 373ms/epoch - 23ms/step
# Epoch 7/100
# 16/16 - 0s - loss: 0.5516 - accuracy: 0.7864 - val_loss: 0.8904 - val_accuracy: 0.7869 - 368ms/epoch - 23ms/step
# Epoch 8/100
# 16/16 - 0s - loss: 0.5891 - accuracy: 0.7700 - val_loss: 0.8232 - val_accuracy: 0.7869 - 352ms/epoch - 22ms/step
# Epoch 9/100
# 16/16 - 0s - loss: 0.5164 - accuracy: 0.7967 - val_loss: 0.7669 - val_accuracy: 0.7869 - 358ms/epoch - 22ms/step
# Epoch 10/100
# 16/16 - 0s - loss: 0.5047 - accuracy: 0.8090 - val_loss: 0.7785 - val_accuracy: 0.7869 - 344ms/epoch - 22ms/step
# Epoch 11/100
# 16/16 - 0s - loss: 0.4880 - accuracy: 0.7864 - val_loss: 0.7316 - val_accuracy: 0.7869 - 350ms/epoch - 22ms/step
# Epoch 12/100
# 16/16 - 0s - loss: 0.4968 - accuracy: 0.7947 - val_loss: 0.7749 - val_accuracy: 0.7869 - 345ms/epoch - 22ms/step
# Epoch 13/100
# 16/16 - 0s - loss: 0.4631 - accuracy: 0.8152 - val_loss: 0.6743 - val_accuracy: 0.7869 - 346ms/epoch - 22ms/step
# Epoch 14/100
# 16/16 - 0s - loss: 0.5093 - accuracy: 0.8070 - val_loss: 0.7211 - val_accuracy: 0.7787 - 349ms/epoch - 22ms/step
# Epoch 15/100
# 16/16 - 0s - loss: 0.4884 - accuracy: 0.7988 - val_loss: 0.6593 - val_accuracy: 0.7787 - 348ms/epoch - 22ms/step
# Epoch 16/100
# 16/16 - 0s - loss: 0.4318 - accuracy: 0.8214 - val_loss: 0.6129 - val_accuracy: 0.7705 - 365ms/epoch - 23ms/step
# Epoch 17/100
# 16/16 - 0s - loss: 0.4615 - accuracy: 0.8172 - val_loss: 0.5844 - val_accuracy: 0.7705 - 350ms/epoch - 22ms/step
# Epoch 18/100
# 16/16 - 0s - loss: 0.5090 - accuracy: 0.7988 - val_loss: 0.6415 - val_accuracy: 0.7787 - 353ms/epoch - 22ms/step
# Epoch 19/100
# 16/16 - 0s - loss: 0.4387 - accuracy: 0.8255 - val_loss: 0.5753 - val_accuracy: 0.7705 - 373ms/epoch - 23ms/step
# Epoch 20/100
# 16/16 - 0s - loss: 0.4263 - accuracy: 0.8234 - val_loss: 0.5820 - val_accuracy: 0.7787 - 367ms/epoch - 23ms/step
# Epoch 21/100
# 16/16 - 0s - loss: 0.4163 - accuracy: 0.8398 - val_loss: 0.5318 - val_accuracy: 0.7787 - 350ms/epoch - 22ms/step
# Epoch 22/100
# 16/16 - 0s - loss: 0.4578 - accuracy: 0.8193 - val_loss: 0.5664 - val_accuracy: 0.7869 - 353ms/epoch - 22ms/step
# Epoch 23/100
# 16/16 - 0s - loss: 0.4219 - accuracy: 0.8193 - val_loss: 0.5219 - val_accuracy: 0.7951 - 359ms/epoch - 22ms/step
# Epoch 24/100
# 16/16 - 0s - loss: 0.4249 - accuracy: 0.8255 - val_loss: 0.5492 - val_accuracy: 0.8115 - 342ms/epoch - 21ms/step
# Epoch 25/100
# 16/16 - 0s - loss: 0.4650 - accuracy: 0.8070 - val_loss: 0.5276 - val_accuracy: 0.7869 - 343ms/epoch - 21ms/step
# Epoch 26/100
# 16/16 - 0s - loss: 0.4381 - accuracy: 0.8316 - val_loss: 0.5467 - val_accuracy: 0.8033 - 348ms/epoch - 22ms/step
# Epoch 27/100
# 16/16 - 0s - loss: 0.4447 - accuracy: 0.8070 - val_loss: 0.5326 - val_accuracy: 0.7951 - 344ms/epoch - 22ms/step
# Epoch 28/100
# 16/16 - 0s - loss: 0.4337 - accuracy: 0.8152 - val_loss: 0.5093 - val_accuracy: 0.8033 - 381ms/epoch - 24ms/step
# Epoch 29/100
# 16/16 - 0s - loss: 0.4226 - accuracy: 0.8357 - val_loss: 0.5106 - val_accuracy: 0.8115 - 373ms/epoch - 23ms/step
# Epoch 30/100
# 16/16 - 0s - loss: 0.4156 - accuracy: 0.8255 - val_loss: 0.5191 - val_accuracy: 0.8115 - 370ms/epoch - 23ms/step
# Epoch 31/100
# 16/16 - 0s - loss: 0.4309 - accuracy: 0.8296 - val_loss: 0.5099 - val_accuracy: 0.8115 - 375ms/epoch - 23ms/step
# Epoch 32/100
# 16/16 - 0s - loss: 0.4177 - accuracy: 0.8357 - val_loss: 0.5131 - val_accuracy: 0.7951 - 371ms/epoch - 23ms/step
# Epoch 33/100
# 16/16 - 0s - loss: 0.3951 - accuracy: 0.8357 - val_loss: 0.5113 - val_accuracy: 0.7951 - 370ms/epoch - 23ms/step
# Epoch 34/100
# 16/16 - 0s - loss: 0.3966 - accuracy: 0.8316 - val_loss: 0.5313 - val_accuracy: 0.8033 - 374ms/epoch - 23ms/step
# Epoch 35/100
# 16/16 - 0s - loss: 0.4016 - accuracy: 0.8316 - val_loss: 0.5373 - val_accuracy: 0.7869 - 363ms/epoch - 23ms/step
# Epoch 36/100
# 16/16 - 0s - loss: 0.3749 - accuracy: 0.8542 - val_loss: 0.5290 - val_accuracy: 0.8033 - 379ms/epoch - 24ms/step
# Epoch 37/100
# 16/16 - 0s - loss: 0.4195 - accuracy: 0.8275 - val_loss: 0.5204 - val_accuracy: 0.8033 - 378ms/epoch - 24ms/step
# Epoch 38/100
# 16/16 - 0s - loss: 0.3903 - accuracy: 0.8460 - val_loss: 0.5023 - val_accuracy: 0.7869 - 365ms/epoch - 23ms/step
# Epoch 39/100
# 16/16 - 0s - loss: 0.4361 - accuracy: 0.8275 - val_loss: 0.5080 - val_accuracy: 0.8115 - 360ms/epoch - 22ms/step
# Epoch 40/100
# 16/16 - 0s - loss: 0.4072 - accuracy: 0.8398 - val_loss: 0.5098 - val_accuracy: 0.7869 - 363ms/epoch - 23ms/step
# Epoch 41/100
# 16/16 - 0s - loss: 0.3950 - accuracy: 0.8234 - val_loss: 0.5002 - val_accuracy: 0.8279 - 367ms/epoch - 23ms/step
# Epoch 42/100
# 16/16 - 0s - loss: 0.3926 - accuracy: 0.8337 - val_loss: 0.4924 - val_accuracy: 0.8197 - 365ms/epoch - 23ms/step
# Epoch 43/100
# 16/16 - 0s - loss: 0.4024 - accuracy: 0.8316 - val_loss: 0.5004 - val_accuracy: 0.8115 - 366ms/epoch - 23ms/step
# Epoch 44/100
# 16/16 - 0s - loss: 0.3610 - accuracy: 0.8563 - val_loss: 0.5051 - val_accuracy: 0.8279 - 354ms/epoch - 22ms/step
# Epoch 45/100
# 16/16 - 0s - loss: 0.3961 - accuracy: 0.8316 - val_loss: 0.5035 - val_accuracy: 0.8279 - 353ms/epoch - 22ms/step
# Epoch 46/100
# 16/16 - 0s - loss: 0.3730 - accuracy: 0.8542 - val_loss: 0.5282 - val_accuracy: 0.8279 - 344ms/epoch - 21ms/step
# Epoch 47/100
# 16/16 - 0s - loss: 0.3520 - accuracy: 0.8439 - val_loss: 0.5303 - val_accuracy: 0.8115 - 348ms/epoch - 22ms/step
# Epoch 48/100
# 16/16 - 0s - loss: 0.3717 - accuracy: 0.8460 - val_loss: 0.5511 - val_accuracy: 0.8197 - 345ms/epoch - 22ms/step
# Epoch 49/100
# 16/16 - 0s - loss: 0.3426 - accuracy: 0.8706 - val_loss: 0.5319 - val_accuracy: 0.8115 - 344ms/epoch - 21ms/step
# Epoch 50/100
# 16/16 - 0s - loss: 0.3991 - accuracy: 0.8480 - val_loss: 0.5375 - val_accuracy: 0.8115 - 352ms/epoch - 22ms/step
# Epoch 51/100
# 16/16 - 0s - loss: 0.3670 - accuracy: 0.8583 - val_loss: 0.4961 - val_accuracy: 0.8115 - 361ms/epoch - 23ms/step
# Epoch 52/100
# Restoring model weights from the end of the best epoch: 42.
# 16/16 - 0s - loss: 0.3854 - accuracy: 0.8460 - val_loss: 0.5160 - val_accuracy: 0.8033 - 350ms/epoch - 22ms/step
# Epoch 52: early stopping
# 4/4 [==============================] - 0s 5ms/step
# Epoch 1/100
# 16/16 - 3s - loss: 1.4373 - accuracy: 0.6920 - val_loss: 1.0524 - val_accuracy: 0.7623 - 3s/epoch - 157ms/step
# Epoch 2/100
# 16/16 - 0s - loss: 0.8471 - accuracy: 0.7782 - val_loss: 1.0313 - val_accuracy: 0.7623 - 350ms/epoch - 22ms/step
# Epoch 3/100
# 16/16 - 0s - loss: 0.6284 - accuracy: 0.7803 - val_loss: 0.9792 - val_accuracy: 0.7623 - 347ms/epoch - 22ms/step
# Epoch 4/100
# 16/16 - 0s - loss: 0.6245 - accuracy: 0.7782 - val_loss: 0.9240 - val_accuracy: 0.7623 - 350ms/epoch - 22ms/step
# Epoch 5/100
# 16/16 - 0s - loss: 0.6294 - accuracy: 0.7947 - val_loss: 0.9455 - val_accuracy: 0.7623 - 344ms/epoch - 21ms/step
# Epoch 6/100
# 16/16 - 0s - loss: 0.5767 - accuracy: 0.8008 - val_loss: 0.8618 - val_accuracy: 0.7623 - 350ms/epoch - 22ms/step
# Epoch 7/100
# 16/16 - 0s - loss: 0.5904 - accuracy: 0.7680 - val_loss: 0.8007 - val_accuracy: 0.7623 - 351ms/epoch - 22ms/step
# Epoch 8/100
# 16/16 - 0s - loss: 0.5752 - accuracy: 0.7823 - val_loss: 0.7871 - val_accuracy: 0.7623 - 344ms/epoch - 21ms/step
# Epoch 9/100
# 16/16 - 0s - loss: 0.5223 - accuracy: 0.8049 - val_loss: 0.7681 - val_accuracy: 0.7705 - 352ms/epoch - 22ms/step
# Epoch 10/100
# 16/16 - 0s - loss: 0.5222 - accuracy: 0.8008 - val_loss: 0.7460 - val_accuracy: 0.7705 - 350ms/epoch - 22ms/step
# Epoch 11/100
# 16/16 - 0s - loss: 0.5476 - accuracy: 0.7967 - val_loss: 0.7068 - val_accuracy: 0.7705 - 347ms/epoch - 22ms/step
# Epoch 12/100
# 16/16 - 0s - loss: 0.5132 - accuracy: 0.7906 - val_loss: 0.6798 - val_accuracy: 0.7705 - 346ms/epoch - 22ms/step
# Epoch 13/100
# 16/16 - 0s - loss: 0.5157 - accuracy: 0.7885 - val_loss: 0.6676 - val_accuracy: 0.7705 - 353ms/epoch - 22ms/step
# Epoch 14/100
# 16/16 - 0s - loss: 0.5139 - accuracy: 0.7782 - val_loss: 0.6809 - val_accuracy: 0.7787 - 342ms/epoch - 21ms/step
# Epoch 15/100
# 16/16 - 0s - loss: 0.4950 - accuracy: 0.8131 - val_loss: 0.6275 - val_accuracy: 0.7705 - 345ms/epoch - 22ms/step
# Epoch 16/100
# 16/16 - 0s - loss: 0.4790 - accuracy: 0.8029 - val_loss: 0.5812 - val_accuracy: 0.7787 - 377ms/epoch - 24ms/step
# Epoch 17/100
# 16/16 - 0s - loss: 0.5055 - accuracy: 0.8111 - val_loss: 0.6020 - val_accuracy: 0.7787 - 354ms/epoch - 22ms/step
# Epoch 18/100
# 16/16 - 0s - loss: 0.4970 - accuracy: 0.8214 - val_loss: 0.5786 - val_accuracy: 0.7787 - 379ms/epoch - 24ms/step
# Epoch 19/100
# 16/16 - 0s - loss: 0.4910 - accuracy: 0.7885 - val_loss: 0.5845 - val_accuracy: 0.7787 - 356ms/epoch - 22ms/step
# Epoch 20/100
# 16/16 - 0s - loss: 0.4729 - accuracy: 0.8049 - val_loss: 0.5449 - val_accuracy: 0.7787 - 352ms/epoch - 22ms/step
# Epoch 21/100
# 16/16 - 0s - loss: 0.4456 - accuracy: 0.8090 - val_loss: 0.5149 - val_accuracy: 0.7869 - 372ms/epoch - 23ms/step
# Epoch 22/100
# 16/16 - 0s - loss: 0.4541 - accuracy: 0.8275 - val_loss: 0.5414 - val_accuracy: 0.7869 - 376ms/epoch - 24ms/step
# Epoch 23/100
# 16/16 - 0s - loss: 0.4499 - accuracy: 0.8131 - val_loss: 0.5405 - val_accuracy: 0.7787 - 368ms/epoch - 23ms/step
# Epoch 24/100
# 16/16 - 0s - loss: 0.4620 - accuracy: 0.7926 - val_loss: 0.5369 - val_accuracy: 0.7951 - 375ms/epoch - 23ms/step
# Epoch 25/100
# 16/16 - 0s - loss: 0.4367 - accuracy: 0.8296 - val_loss: 0.4982 - val_accuracy: 0.7787 - 394ms/epoch - 25ms/step
# Epoch 26/100
# 16/16 - 0s - loss: 0.4565 - accuracy: 0.8131 - val_loss: 0.4842 - val_accuracy: 0.7869 - 403ms/epoch - 25ms/step
# Epoch 27/100
# 16/16 - 0s - loss: 0.4501 - accuracy: 0.8214 - val_loss: 0.4965 - val_accuracy: 0.7951 - 370ms/epoch - 23ms/step
# Epoch 28/100
# 16/16 - 0s - loss: 0.4390 - accuracy: 0.8090 - val_loss: 0.4760 - val_accuracy: 0.8033 - 402ms/epoch - 25ms/step
# Epoch 29/100
# 16/16 - 0s - loss: 0.4369 - accuracy: 0.8152 - val_loss: 0.4756 - val_accuracy: 0.8033 - 367ms/epoch - 23ms/step
# Epoch 30/100
# 16/16 - 0s - loss: 0.4542 - accuracy: 0.8234 - val_loss: 0.4852 - val_accuracy: 0.8197 - 353ms/epoch - 22ms/step
# Epoch 31/100
# 16/16 - 0s - loss: 0.4209 - accuracy: 0.8234 - val_loss: 0.4742 - val_accuracy: 0.8115 - 375ms/epoch - 23ms/step
# Epoch 32/100
# 16/16 - 0s - loss: 0.4058 - accuracy: 0.8398 - val_loss: 0.4658 - val_accuracy: 0.8033 - 374ms/epoch - 23ms/step
# Epoch 33/100
# 16/16 - 0s - loss: 0.4284 - accuracy: 0.8234 - val_loss: 0.4718 - val_accuracy: 0.7869 - 357ms/epoch - 22ms/step
# Epoch 34/100
# 16/16 - 0s - loss: 0.3820 - accuracy: 0.8542 - val_loss: 0.4676 - val_accuracy: 0.7787 - 383ms/epoch - 24ms/step
# Epoch 35/100
# 16/16 - 0s - loss: 0.4281 - accuracy: 0.8337 - val_loss: 0.4734 - val_accuracy: 0.7869 - 378ms/epoch - 24ms/step
# Epoch 36/100
# 16/16 - 0s - loss: 0.4277 - accuracy: 0.8172 - val_loss: 0.4784 - val_accuracy: 0.7787 - 371ms/epoch - 23ms/step
# Epoch 37/100
# 16/16 - 0s - loss: 0.4160 - accuracy: 0.8234 - val_loss: 0.5012 - val_accuracy: 0.7869 - 367ms/epoch - 23ms/step
# Epoch 38/100
# 16/16 - 0s - loss: 0.4090 - accuracy: 0.8398 - val_loss: 0.4965 - val_accuracy: 0.7951 - 384ms/epoch - 24ms/step
# Epoch 39/100
# 16/16 - 0s - loss: 0.4052 - accuracy: 0.8337 - val_loss: 0.4845 - val_accuracy: 0.8033 - 404ms/epoch - 25ms/step
# Epoch 40/100
# 16/16 - 0s - loss: 0.4123 - accuracy: 0.8378 - val_loss: 0.4809 - val_accuracy: 0.8197 - 378ms/epoch - 24ms/step
# Epoch 41/100
# 16/16 - 0s - loss: 0.4361 - accuracy: 0.8172 - val_loss: 0.4656 - val_accuracy: 0.8033 - 402ms/epoch - 25ms/step
# Epoch 42/100
# 16/16 - 0s - loss: 0.3774 - accuracy: 0.8460 - val_loss: 0.4592 - val_accuracy: 0.7869 - 416ms/epoch - 26ms/step
# Epoch 43/100
# 16/16 - 0s - loss: 0.3986 - accuracy: 0.8316 - val_loss: 0.4772 - val_accuracy: 0.8197 - 366ms/epoch - 23ms/step
# Epoch 44/100
# 16/16 - 0s - loss: 0.3912 - accuracy: 0.8398 - val_loss: 0.4610 - val_accuracy: 0.8115 - 355ms/epoch - 22ms/step
# Epoch 45/100
# 16/16 - 0s - loss: 0.3846 - accuracy: 0.8193 - val_loss: 0.4623 - val_accuracy: 0.7951 - 350ms/epoch - 22ms/step
# Epoch 46/100
# 16/16 - 0s - loss: 0.3846 - accuracy: 0.8357 - val_loss: 0.4726 - val_accuracy: 0.8033 - 346ms/epoch - 22ms/step
# Epoch 47/100
# 16/16 - 0s - loss: 0.3902 - accuracy: 0.8255 - val_loss: 0.4784 - val_accuracy: 0.8197 - 363ms/epoch - 23ms/step
# Epoch 48/100
# 16/16 - 0s - loss: 0.3877 - accuracy: 0.8419 - val_loss: 0.4667 - val_accuracy: 0.8115 - 372ms/epoch - 23ms/step
# Epoch 49/100
# 16/16 - 0s - loss: 0.3810 - accuracy: 0.8439 - val_loss: 0.4624 - val_accuracy: 0.8033 - 370ms/epoch - 23ms/step
# Epoch 50/100
# 16/16 - 0s - loss: 0.3745 - accuracy: 0.8563 - val_loss: 0.4824 - val_accuracy: 0.8197 - 369ms/epoch - 23ms/step
# Epoch 51/100
# 16/16 - 0s - loss: 0.3834 - accuracy: 0.8501 - val_loss: 0.4779 - val_accuracy: 0.7951 - 390ms/epoch - 24ms/step
# Epoch 52/100
# Restoring model weights from the end of the best epoch: 42.
# 16/16 - 0s - loss: 0.3780 - accuracy: 0.8480 - val_loss: 0.4630 - val_accuracy: 0.8115 - 353ms/epoch - 22ms/step
# Epoch 52: early stopping
# 4/4 [==============================] - 0s 5ms/step
# Epoch 1/100
# 16/16 - 3s - loss: 1.6308 - accuracy: 0.5873 - val_loss: 1.0176 - val_accuracy: 0.8197 - 3s/epoch - 159ms/step
# Epoch 2/100
# 16/16 - 0s - loss: 0.7867 - accuracy: 0.7762 - val_loss: 1.0368 - val_accuracy: 0.8197 - 358ms/epoch - 22ms/step
# Epoch 3/100
# 16/16 - 0s - loss: 0.6483 - accuracy: 0.7823 - val_loss: 0.9255 - val_accuracy: 0.8197 - 358ms/epoch - 22ms/step
# Epoch 4/100
# 16/16 - 0s - loss: 0.6021 - accuracy: 0.7803 - val_loss: 0.9328 - val_accuracy: 0.8279 - 356ms/epoch - 22ms/step
# Epoch 5/100
# 16/16 - 0s - loss: 0.5853 - accuracy: 0.7721 - val_loss: 0.9161 - val_accuracy: 0.8279 - 363ms/epoch - 23ms/step
# Epoch 6/100
# 16/16 - 0s - loss: 0.5619 - accuracy: 0.7639 - val_loss: 0.8567 - val_accuracy: 0.8279 - 366ms/epoch - 23ms/step
# Epoch 7/100
# 16/16 - 0s - loss: 0.5654 - accuracy: 0.7823 - val_loss: 0.8392 - val_accuracy: 0.8279 - 371ms/epoch - 23ms/step
# Epoch 8/100
# 16/16 - 0s - loss: 0.5566 - accuracy: 0.7803 - val_loss: 0.8458 - val_accuracy: 0.8361 - 362ms/epoch - 23ms/step
# Epoch 9/100
# 16/16 - 0s - loss: 0.5351 - accuracy: 0.7967 - val_loss: 0.8030 - val_accuracy: 0.8361 - 374ms/epoch - 23ms/step
# Epoch 10/100
# 16/16 - 0s - loss: 0.5109 - accuracy: 0.7885 - val_loss: 0.7692 - val_accuracy: 0.8361 - 392ms/epoch - 25ms/step
# Epoch 11/100
# 16/16 - 0s - loss: 0.4810 - accuracy: 0.8029 - val_loss: 0.6929 - val_accuracy: 0.8115 - 367ms/epoch - 23ms/step
# Epoch 12/100
# 16/16 - 0s - loss: 0.4857 - accuracy: 0.7844 - val_loss: 0.7017 - val_accuracy: 0.8279 - 366ms/epoch - 23ms/step
# Epoch 13/100
# 16/16 - 0s - loss: 0.4751 - accuracy: 0.7967 - val_loss: 0.6514 - val_accuracy: 0.8361 - 357ms/epoch - 22ms/step
# Epoch 14/100
# 16/16 - 0s - loss: 0.4820 - accuracy: 0.8029 - val_loss: 0.6777 - val_accuracy: 0.8115 - 355ms/epoch - 22ms/step
# Epoch 15/100
# 16/16 - 0s - loss: 0.5085 - accuracy: 0.7926 - val_loss: 0.6458 - val_accuracy: 0.8197 - 358ms/epoch - 22ms/step
# Epoch 16/100
# 16/16 - 0s - loss: 0.4809 - accuracy: 0.8029 - val_loss: 0.6582 - val_accuracy: 0.8197 - 352ms/epoch - 22ms/step
# Epoch 17/100
# 16/16 - 0s - loss: 0.4691 - accuracy: 0.8152 - val_loss: 0.5700 - val_accuracy: 0.8279 - 347ms/epoch - 22ms/step
# Epoch 18/100
# 16/16 - 0s - loss: 0.4653 - accuracy: 0.8152 - val_loss: 0.5886 - val_accuracy: 0.8607 - 353ms/epoch - 22ms/step
# Epoch 19/100
# 16/16 - 0s - loss: 0.5078 - accuracy: 0.8029 - val_loss: 0.5910 - val_accuracy: 0.8607 - 353ms/epoch - 22ms/step
# Epoch 20/100
# 16/16 - 0s - loss: 0.4594 - accuracy: 0.8255 - val_loss: 0.5555 - val_accuracy: 0.8525 - 356ms/epoch - 22ms/step
# Epoch 21/100
# 16/16 - 0s - loss: 0.4907 - accuracy: 0.8029 - val_loss: 0.5122 - val_accuracy: 0.8689 - 353ms/epoch - 22ms/step
# Epoch 22/100
# 16/16 - 0s - loss: 0.4720 - accuracy: 0.8172 - val_loss: 0.5491 - val_accuracy: 0.8689 - 346ms/epoch - 22ms/step
# Epoch 23/100
# 16/16 - 0s - loss: 0.4813 - accuracy: 0.8090 - val_loss: 0.5055 - val_accuracy: 0.8279 - 352ms/epoch - 22ms/step
# Epoch 24/100
# 16/16 - 0s - loss: 0.4541 - accuracy: 0.8111 - val_loss: 0.5033 - val_accuracy: 0.8197 - 354ms/epoch - 22ms/step
# Epoch 25/100
# 16/16 - 0s - loss: 0.4475 - accuracy: 0.8152 - val_loss: 0.4778 - val_accuracy: 0.8607 - 349ms/epoch - 22ms/step
# Epoch 26/100
# 16/16 - 0s - loss: 0.4693 - accuracy: 0.8111 - val_loss: 0.5151 - val_accuracy: 0.8361 - 351ms/epoch - 22ms/step
# Epoch 27/100
# 16/16 - 0s - loss: 0.4505 - accuracy: 0.8214 - val_loss: 0.4690 - val_accuracy: 0.8525 - 356ms/epoch - 22ms/step
# Epoch 28/100
# 16/16 - 0s - loss: 0.4704 - accuracy: 0.8172 - val_loss: 0.4882 - val_accuracy: 0.8689 - 353ms/epoch - 22ms/step
# Epoch 29/100
# 16/16 - 0s - loss: 0.4466 - accuracy: 0.8172 - val_loss: 0.4467 - val_accuracy: 0.8361 - 356ms/epoch - 22ms/step
# Epoch 30/100
# 16/16 - 0s - loss: 0.4271 - accuracy: 0.8214 - val_loss: 0.4627 - val_accuracy: 0.8525 - 356ms/epoch - 22ms/step
# Epoch 31/100
# 16/16 - 0s - loss: 0.4377 - accuracy: 0.8090 - val_loss: 0.4575 - val_accuracy: 0.8443 - 348ms/epoch - 22ms/step
# Epoch 32/100
# 16/16 - 0s - loss: 0.4196 - accuracy: 0.8398 - val_loss: 0.4037 - val_accuracy: 0.8525 - 353ms/epoch - 22ms/step
# Epoch 33/100
# 16/16 - 0s - loss: 0.4445 - accuracy: 0.8255 - val_loss: 0.4335 - val_accuracy: 0.8279 - 358ms/epoch - 22ms/step
# Epoch 34/100
# 16/16 - 0s - loss: 0.4333 - accuracy: 0.8131 - val_loss: 0.4258 - val_accuracy: 0.8689 - 348ms/epoch - 22ms/step
# Epoch 35/100
# 16/16 - 0s - loss: 0.4174 - accuracy: 0.8296 - val_loss: 0.4129 - val_accuracy: 0.8361 - 353ms/epoch - 22ms/step
# Epoch 36/100
# 16/16 - 0s - loss: 0.4209 - accuracy: 0.8275 - val_loss: 0.4205 - val_accuracy: 0.8197 - 343ms/epoch - 21ms/step
# Epoch 37/100
# 16/16 - 0s - loss: 0.4101 - accuracy: 0.8337 - val_loss: 0.4354 - val_accuracy: 0.8361 - 344ms/epoch - 22ms/step
# Epoch 38/100
# 16/16 - 0s - loss: 0.4216 - accuracy: 0.8214 - val_loss: 0.3964 - val_accuracy: 0.8361 - 353ms/epoch - 22ms/step
# Epoch 39/100
# 16/16 - 0s - loss: 0.4120 - accuracy: 0.8378 - val_loss: 0.4040 - val_accuracy: 0.8443 - 380ms/epoch - 24ms/step
# Epoch 40/100
# 16/16 - 0s - loss: 0.4291 - accuracy: 0.8234 - val_loss: 0.4162 - val_accuracy: 0.8689 - 349ms/epoch - 22ms/step
# Epoch 41/100
# 16/16 - 0s - loss: 0.3813 - accuracy: 0.8542 - val_loss: 0.3896 - val_accuracy: 0.8443 - 351ms/epoch - 22ms/step
# Epoch 42/100
# 16/16 - 0s - loss: 0.3798 - accuracy: 0.8583 - val_loss: 0.3800 - val_accuracy: 0.8607 - 351ms/epoch - 22ms/step
# Epoch 43/100
# 16/16 - 0s - loss: 0.4460 - accuracy: 0.8337 - val_loss: 0.3911 - val_accuracy: 0.8525 - 349ms/epoch - 22ms/step
# Epoch 44/100
# 16/16 - 0s - loss: 0.4022 - accuracy: 0.8296 - val_loss: 0.4398 - val_accuracy: 0.8607 - 350ms/epoch - 22ms/step
# Epoch 45/100
# 16/16 - 0s - loss: 0.3926 - accuracy: 0.8357 - val_loss: 0.3793 - val_accuracy: 0.8607 - 350ms/epoch - 22ms/step
# Epoch 46/100
# 16/16 - 0s - loss: 0.4293 - accuracy: 0.8316 - val_loss: 0.4108 - val_accuracy: 0.8361 - 346ms/epoch - 22ms/step
# Epoch 47/100
# 16/16 - 0s - loss: 0.4304 - accuracy: 0.8337 - val_loss: 0.4004 - val_accuracy: 0.8525 - 350ms/epoch - 22ms/step
# Epoch 48/100
# 16/16 - 0s - loss: 0.3885 - accuracy: 0.8357 - val_loss: 0.3843 - val_accuracy: 0.8689 - 348ms/epoch - 22ms/step
# Epoch 49/100
# 16/16 - 0s - loss: 0.4100 - accuracy: 0.8296 - val_loss: 0.3924 - val_accuracy: 0.8689 - 351ms/epoch - 22ms/step
# Epoch 50/100
# 16/16 - 0s - loss: 0.3931 - accuracy: 0.8357 - val_loss: 0.3985 - val_accuracy: 0.8607 - 361ms/epoch - 23ms/step
# Epoch 51/100
# 16/16 - 0s - loss: 0.4079 - accuracy: 0.8501 - val_loss: 0.3973 - val_accuracy: 0.8852 - 355ms/epoch - 22ms/step
# Epoch 52/100
# 16/16 - 0s - loss: 0.3940 - accuracy: 0.8419 - val_loss: 0.4003 - val_accuracy: 0.8361 - 370ms/epoch - 23ms/step
# Epoch 53/100
# 16/16 - 0s - loss: 0.3865 - accuracy: 0.8337 - val_loss: 0.3872 - val_accuracy: 0.8525 - 359ms/epoch - 22ms/step
# Epoch 54/100
# 16/16 - 0s - loss: 0.3761 - accuracy: 0.8439 - val_loss: 0.4049 - val_accuracy: 0.8525 - 357ms/epoch - 22ms/step
# Epoch 55/100
# Restoring model weights from the end of the best epoch: 45.
# 16/16 - 0s - loss: 0.4352 - accuracy: 0.8316 - val_loss: 0.3901 - val_accuracy: 0.8689 - 370ms/epoch - 23ms/step
# Epoch 55: early stopping
# 4/4 [==============================] - 0s 5ms/step
# Epoch 1/100
# 16/16 - 3s - loss: 1.2274 - accuracy: 0.7029 - val_loss: 1.0822 - val_accuracy: 0.7521 - 3s/epoch - 180ms/step
# Epoch 2/100
# 16/16 - 0s - loss: 0.8153 - accuracy: 0.7439 - val_loss: 1.0121 - val_accuracy: 0.7686 - 355ms/epoch - 22ms/step
# Epoch 3/100
# 16/16 - 0s - loss: 0.6842 - accuracy: 0.7705 - val_loss: 0.9708 - val_accuracy: 0.7686 - 360ms/epoch - 22ms/step
# Epoch 4/100
# 16/16 - 0s - loss: 0.6253 - accuracy: 0.7664 - val_loss: 0.9579 - val_accuracy: 0.7686 - 360ms/epoch - 22ms/step
# Epoch 5/100
# 16/16 - 0s - loss: 0.6365 - accuracy: 0.7746 - val_loss: 0.9506 - val_accuracy: 0.7686 - 361ms/epoch - 23ms/step
# Epoch 6/100
# 16/16 - 0s - loss: 0.5821 - accuracy: 0.8012 - val_loss: 0.9231 - val_accuracy: 0.7686 - 380ms/epoch - 24ms/step
# Epoch 7/100
# 16/16 - 0s - loss: 0.6094 - accuracy: 0.7807 - val_loss: 0.9076 - val_accuracy: 0.7686 - 364ms/epoch - 23ms/step
# Epoch 8/100
# 16/16 - 0s - loss: 0.5176 - accuracy: 0.7828 - val_loss: 0.8448 - val_accuracy: 0.7686 - 360ms/epoch - 23ms/step
# Epoch 9/100
# 16/16 - 0s - loss: 0.5320 - accuracy: 0.7848 - val_loss: 0.8377 - val_accuracy: 0.7686 - 364ms/epoch - 23ms/step
# Epoch 10/100
# 16/16 - 0s - loss: 0.5371 - accuracy: 0.7930 - val_loss: 0.8473 - val_accuracy: 0.7686 - 358ms/epoch - 22ms/step
# Epoch 11/100
# 16/16 - 0s - loss: 0.5292 - accuracy: 0.7910 - val_loss: 0.7894 - val_accuracy: 0.7603 - 373ms/epoch - 23ms/step
# Epoch 12/100
# 16/16 - 0s - loss: 0.5163 - accuracy: 0.7869 - val_loss: 0.7864 - val_accuracy: 0.7521 - 353ms/epoch - 22ms/step
# Epoch 13/100
# 16/16 - 0s - loss: 0.5232 - accuracy: 0.7971 - val_loss: 0.7626 - val_accuracy: 0.7686 - 355ms/epoch - 22ms/step
# Epoch 14/100
# 16/16 - 0s - loss: 0.5181 - accuracy: 0.7848 - val_loss: 0.7799 - val_accuracy: 0.7521 - 359ms/epoch - 22ms/step
# Epoch 15/100
# 16/16 - 0s - loss: 0.4776 - accuracy: 0.8053 - val_loss: 0.7016 - val_accuracy: 0.7521 - 356ms/epoch - 22ms/step
# Epoch 16/100
# 16/16 - 0s - loss: 0.4901 - accuracy: 0.7848 - val_loss: 0.6273 - val_accuracy: 0.7686 - 357ms/epoch - 22ms/step
# Epoch 17/100
# 16/16 - 0s - loss: 0.4704 - accuracy: 0.8053 - val_loss: 0.6857 - val_accuracy: 0.7769 - 358ms/epoch - 22ms/step
# Epoch 18/100
# 16/16 - 0s - loss: 0.4362 - accuracy: 0.8299 - val_loss: 0.6008 - val_accuracy: 0.7769 - 354ms/epoch - 22ms/step
# Epoch 19/100
# 16/16 - 0s - loss: 0.4676 - accuracy: 0.8258 - val_loss: 0.6216 - val_accuracy: 0.7686 - 354ms/epoch - 22ms/step
# Epoch 20/100
# 16/16 - 0s - loss: 0.4448 - accuracy: 0.8279 - val_loss: 0.5993 - val_accuracy: 0.7521 - 365ms/epoch - 23ms/step
# Epoch 21/100
# 16/16 - 0s - loss: 0.4474 - accuracy: 0.8176 - val_loss: 0.6077 - val_accuracy: 0.7769 - 356ms/epoch - 22ms/step
# Epoch 22/100
# 16/16 - 0s - loss: 0.4692 - accuracy: 0.8156 - val_loss: 0.5887 - val_accuracy: 0.7769 - 366ms/epoch - 23ms/step
# Epoch 23/100
# 16/16 - 0s - loss: 0.4844 - accuracy: 0.8053 - val_loss: 0.6177 - val_accuracy: 0.7686 - 360ms/epoch - 22ms/step
# Epoch 24/100
# 16/16 - 0s - loss: 0.4479 - accuracy: 0.8279 - val_loss: 0.5469 - val_accuracy: 0.7769 - 360ms/epoch - 23ms/step
# Epoch 25/100
# 16/16 - 0s - loss: 0.4676 - accuracy: 0.8258 - val_loss: 0.5462 - val_accuracy: 0.7521 - 362ms/epoch - 23ms/step
# Epoch 26/100
# 16/16 - 0s - loss: 0.4537 - accuracy: 0.8156 - val_loss: 0.5416 - val_accuracy: 0.7769 - 351ms/epoch - 22ms/step
# Epoch 27/100
# 16/16 - 0s - loss: 0.4034 - accuracy: 0.8176 - val_loss: 0.5422 - val_accuracy: 0.7686 - 357ms/epoch - 22ms/step
# Epoch 28/100
# 16/16 - 0s - loss: 0.4571 - accuracy: 0.8012 - val_loss: 0.5513 - val_accuracy: 0.7934 - 355ms/epoch - 22ms/step
# Epoch 29/100
# 16/16 - 0s - loss: 0.4186 - accuracy: 0.8320 - val_loss: 0.5336 - val_accuracy: 0.7603 - 355ms/epoch - 22ms/step
# Epoch 30/100
# 16/16 - 0s - loss: 0.4162 - accuracy: 0.8381 - val_loss: 0.5258 - val_accuracy: 0.7603 - 356ms/epoch - 22ms/step
# Epoch 31/100
# 16/16 - 0s - loss: 0.4269 - accuracy: 0.8299 - val_loss: 0.5259 - val_accuracy: 0.7769 - 358ms/epoch - 22ms/step
# Epoch 32/100
# 16/16 - 0s - loss: 0.4314 - accuracy: 0.8053 - val_loss: 0.5292 - val_accuracy: 0.7934 - 377ms/epoch - 24ms/step
# Epoch 33/100
# 16/16 - 0s - loss: 0.4013 - accuracy: 0.8381 - val_loss: 0.5307 - val_accuracy: 0.7769 - 378ms/epoch - 24ms/step
# Epoch 34/100
# 16/16 - 0s - loss: 0.4265 - accuracy: 0.8094 - val_loss: 0.5389 - val_accuracy: 0.7769 - 371ms/epoch - 23ms/step
# Epoch 35/100
# 16/16 - 0s - loss: 0.3786 - accuracy: 0.8566 - val_loss: 0.5332 - val_accuracy: 0.7769 - 367ms/epoch - 23ms/step
# Epoch 36/100
# 16/16 - 0s - loss: 0.4130 - accuracy: 0.8176 - val_loss: 0.5405 - val_accuracy: 0.7851 - 367ms/epoch - 23ms/step
# Epoch 37/100
# 16/16 - 0s - loss: 0.4104 - accuracy: 0.8402 - val_loss: 0.5537 - val_accuracy: 0.7438 - 368ms/epoch - 23ms/step
# Epoch 38/100
# 16/16 - 0s - loss: 0.4306 - accuracy: 0.8299 - val_loss: 0.5279 - val_accuracy: 0.7934 - 360ms/epoch - 22ms/step
# Epoch 39/100
# 16/16 - 0s - loss: 0.3931 - accuracy: 0.8361 - val_loss: 0.5223 - val_accuracy: 0.7851 - 355ms/epoch - 22ms/step
# Epoch 40/100
# 16/16 - 0s - loss: 0.3984 - accuracy: 0.8258 - val_loss: 0.5106 - val_accuracy: 0.8099 - 356ms/epoch - 22ms/step
# Epoch 41/100
# 16/16 - 0s - loss: 0.3834 - accuracy: 0.8443 - val_loss: 0.5019 - val_accuracy: 0.7686 - 355ms/epoch - 22ms/step
# Epoch 42/100
# 16/16 - 0s - loss: 0.4417 - accuracy: 0.8279 - val_loss: 0.5121 - val_accuracy: 0.7438 - 353ms/epoch - 22ms/step
# Epoch 43/100
# 16/16 - 0s - loss: 0.3962 - accuracy: 0.8340 - val_loss: 0.5103 - val_accuracy: 0.7851 - 350ms/epoch - 22ms/step
# Epoch 44/100
# 16/16 - 0s - loss: 0.4010 - accuracy: 0.8340 - val_loss: 0.5166 - val_accuracy: 0.7851 - 355ms/epoch - 22ms/step
# Epoch 45/100
# 16/16 - 0s - loss: 0.3997 - accuracy: 0.8545 - val_loss: 0.5096 - val_accuracy: 0.7851 - 355ms/epoch - 22ms/step
# Epoch 46/100
# 16/16 - 0s - loss: 0.3540 - accuracy: 0.8545 - val_loss: 0.5035 - val_accuracy: 0.7934 - 351ms/epoch - 22ms/step
# Epoch 47/100
# 16/16 - 0s - loss: 0.4057 - accuracy: 0.8381 - val_loss: 0.5148 - val_accuracy: 0.7934 - 358ms/epoch - 22ms/step
# Epoch 48/100
# 16/16 - 0s - loss: 0.4065 - accuracy: 0.8340 - val_loss: 0.5131 - val_accuracy: 0.8182 - 354ms/epoch - 22ms/step
# Epoch 49/100
# 16/16 - 0s - loss: 0.3998 - accuracy: 0.8176 - val_loss: 0.5160 - val_accuracy: 0.8017 - 350ms/epoch - 22ms/step
# Epoch 50/100
# 16/16 - 0s - loss: 0.3818 - accuracy: 0.8340 - val_loss: 0.5182 - val_accuracy: 0.7934 - 358ms/epoch - 22ms/step
# Epoch 51/100
# Restoring model weights from the end of the best epoch: 41.
# 16/16 - 0s - loss: 0.3933 - accuracy: 0.8156 - val_loss: 0.5269 - val_accuracy: 0.7934 - 361ms/epoch - 23ms/step
# Epoch 51: early stopping
# 4/4 [==============================] - 0s 5ms/step
#
# Mean accuracy: 0.8160, Standard deviation: 0.0344
#
# Mean recall: [0.94739984 0.26547619 0.4479405 ], Standard deviation: [0.02654559 0.13602721 0.19970946]
#
# Mean ROC AUC: 0.8909, Standard deviation: 0.0279

# %% [markdown]
# ## Converting the target variable to 0/1 (yes no HF)

# %%
def convert2(combined_df):
    if combined_df["hf_type"]==0:
        return 0
    
    else:
        return 1

# %%
combined_df["hf_type"] = combined_df.apply(lambda combined_df: convert2(combined_df), axis=1)

# %%
combined_df["hf_type"].value_counts()
# Out:
# 0    477
# 1    132
# Name: hf_type, dtype: int64

# %%
from sklearn.model_selection import GroupShuffleSplit
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report, accuracy_score, roc_auc_score, recall_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, BatchNormalization, MaxPooling1D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical

# Split the dataset into features (X) and target (y)
X = combined_df.drop(['hf_type', 'study_id', 'subject_id', 'sex', 'nrg_lin_scgk', 'nrg_rot_scgk', 'pwr_lin_scgk', 'pwr_rot_scgk', 'rsp'], axis=1)
y = combined_df['hf_type']

# Extract subject_id as groups
groups = combined_df['subject_id']

# Initialize the GroupShuffleSplit
gss = GroupShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

# Get the train and test indices based on the groups
train_idx, test_idx = next(gss.split(X, y, groups))

# Split the dataset into training and testing sets
X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

# Standardize the input features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# One-hot encode the target variable
encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(y_train)
y_test_enc = encoder.transform(y_test)
y_train_cat = to_categorical(y_train_enc)
y_test_cat = to_categorical(y_test_enc)

# Reshape the input features to fit the 1D CNN model
max_length = X_train.shape[1]
X_train = X_train.reshape((X_train.shape[0], max_length, 1))
X_test = X_test.reshape((X_test.shape[0], max_length, 1))

# Define the model architecture
model = Sequential()

# Add the first convolutional block
model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(max_length, 1)))
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=2))

# Add the second convolutional block
model.add(Conv1D(filters=16, kernel_size=3, activation='relu'))
model.add(Dropout(rate=0.5))
model.add(MaxPooling1D(pool_size=2))

# Add the third convolutional block
model.add(Conv1D(filters=16, kernel_size=3, activation='relu'))
model.add(Dropout(rate=0.5))

# Flatten the output of the convolutional blocks
model.add(Flatten())

# Add the fully connected layers
model.add(Dense(units=1000, activation='relu'))
model.add(Dropout(rate=0.5))
model.add(Dense(units=1000, activation='relu'))
model.add(Dropout(rate=0.5))

# Add the output layer with Softmax activation function
model.add(Dense(units=2, activation='softmax'))

# Define the early stopping callback
early_stopping = EarlyStopping(patience=10, monitor='val_loss', mode='min', verbose=1, restore_best_weights=True)

# Compile the model with categorical crossentropy loss
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model on the combined time series data
model.fit(X_train, y_train_cat, epochs=100, validation_data=(X_test, y_test_cat), callbacks=[early_stopping])


# Evaluate the model on the test set
y_pred_cat = model.predict(X_test)
y_pred = np.argmax(y_pred_cat, axis=1)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")

# Compute recall
recall = recall_score(y_test, y_pred, average=None)
print(f"Recall: {recall}")

# ROC auc
roc_auc = roc_auc_score(y_test, y_pred_cat[:,1])
print(f"Macro-averaged One-vs-Rest ROC AUC score:\n{roc_auc}")
# Out:
# Epoch 1/100
# 15/15 [==============================] - 3s 45ms/step - loss: 1.3651 - accuracy: 0.6632 - val_loss: 0.7109 - val_accuracy: 0.7761
# Epoch 2/100
# 15/15 [==============================] - 0s 27ms/step - loss: 0.7164 - accuracy: 0.6968 - val_loss: 0.7048 - val_accuracy: 0.8358
# Epoch 3/100
# 15/15 [==============================] - 0s 26ms/step - loss: 0.5702 - accuracy: 0.7389 - val_loss: 0.6519 - val_accuracy: 0.8433
# Epoch 4/100
# 15/15 [==============================] - 0s 25ms/step - loss: 0.5568 - accuracy: 0.7453 - val_loss: 0.6488 - val_accuracy: 0.8433
# Epoch 5/100
# 15/15 [==============================] - 0s 26ms/step - loss: 0.5309 - accuracy: 0.7474 - val_loss: 0.6046 - val_accuracy: 0.8433
# Epoch 6/100
# 15/15 [==============================] - 0s 26ms/step - loss: 0.5210 - accuracy: 0.7453 - val_loss: 0.5740 - val_accuracy: 0.8507
# Epoch 7/100
# 15/15 [==============================] - 0s 28ms/step - loss: 0.4833 - accuracy: 0.7726 - val_loss: 0.5514 - val_accuracy: 0.8507
# Epoch 8/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.4905 - accuracy: 0.7684 - val_loss: 0.5426 - val_accuracy: 0.8507
# Epoch 9/100
# 15/15 [==============================] - 0s 27ms/step - loss: 0.4853 - accuracy: 0.7726 - val_loss: 0.5154 - val_accuracy: 0.8433
# Epoch 10/100
# 15/15 [==============================] - 0s 25ms/step - loss: 0.4735 - accuracy: 0.7895 - val_loss: 0.5201 - val_accuracy: 0.8507
# Epoch 11/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.4486 - accuracy: 0.7895 - val_loss: 0.4891 - val_accuracy: 0.8507
# Epoch 12/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.4581 - accuracy: 0.7937 - val_loss: 0.4700 - val_accuracy: 0.8507
# Epoch 13/100
# 15/15 [==============================] - 0s 25ms/step - loss: 0.4519 - accuracy: 0.7958 - val_loss: 0.4780 - val_accuracy: 0.8507
# Epoch 14/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.4149 - accuracy: 0.8000 - val_loss: 0.4487 - val_accuracy: 0.8507
# Epoch 15/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.4219 - accuracy: 0.7979 - val_loss: 0.4133 - val_accuracy: 0.8507
# Epoch 16/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.4102 - accuracy: 0.7979 - val_loss: 0.4278 - val_accuracy: 0.8507
# Epoch 17/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.4326 - accuracy: 0.7916 - val_loss: 0.3957 - val_accuracy: 0.8507
# Epoch 18/100
# 15/15 [==============================] - 0s 25ms/step - loss: 0.4105 - accuracy: 0.7958 - val_loss: 0.3969 - val_accuracy: 0.8507
# Epoch 19/100
# 15/15 [==============================] - 0s 26ms/step - loss: 0.4125 - accuracy: 0.7979 - val_loss: 0.3525 - val_accuracy: 0.8507
# Epoch 20/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.4199 - accuracy: 0.8000 - val_loss: 0.3665 - val_accuracy: 0.8507
# Epoch 21/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.3940 - accuracy: 0.7937 - val_loss: 0.3313 - val_accuracy: 0.8507
# Epoch 22/100
# 15/15 [==============================] - 0s 27ms/step - loss: 0.3929 - accuracy: 0.8211 - val_loss: 0.3236 - val_accuracy: 0.8507
# Epoch 23/100
# 15/15 [==============================] - 0s 26ms/step - loss: 0.4203 - accuracy: 0.8000 - val_loss: 0.3309 - val_accuracy: 0.8507
# Epoch 24/100
# 15/15 [==============================] - 0s 25ms/step - loss: 0.3994 - accuracy: 0.8021 - val_loss: 0.3206 - val_accuracy: 0.8507
# Epoch 25/100
# 15/15 [==============================] - 0s 27ms/step - loss: 0.4154 - accuracy: 0.8063 - val_loss: 0.3030 - val_accuracy: 0.8507
# Epoch 26/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.3959 - accuracy: 0.8084 - val_loss: 0.3080 - val_accuracy: 0.8507
# Epoch 27/100
# 15/15 [==============================] - 0s 30ms/step - loss: 0.3937 - accuracy: 0.8000 - val_loss: 0.2951 - val_accuracy: 0.8507
# Epoch 28/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.3766 - accuracy: 0.8189 - val_loss: 0.2816 - val_accuracy: 0.8507
# Epoch 29/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.4040 - accuracy: 0.8021 - val_loss: 0.2766 - val_accuracy: 0.8507
# Epoch 30/100
# 15/15 [==============================] - 0s 27ms/step - loss: 0.3674 - accuracy: 0.8000 - val_loss: 0.2679 - val_accuracy: 0.8507
# Epoch 31/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.3793 - accuracy: 0.8105 - val_loss: 0.2716 - val_accuracy: 0.8582
# Epoch 32/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.3850 - accuracy: 0.8021 - val_loss: 0.2549 - val_accuracy: 0.8657
# Epoch 33/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.3602 - accuracy: 0.8358 - val_loss: 0.2622 - val_accuracy: 0.8657
# Epoch 34/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.3588 - accuracy: 0.8253 - val_loss: 0.3044 - val_accuracy: 0.8806
# Epoch 35/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.3599 - accuracy: 0.8400 - val_loss: 0.2933 - val_accuracy: 0.8806
# Epoch 36/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.3583 - accuracy: 0.8274 - val_loss: 0.2752 - val_accuracy: 0.8731
# Epoch 37/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.3393 - accuracy: 0.8484 - val_loss: 0.2575 - val_accuracy: 0.9030
# Epoch 38/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.3816 - accuracy: 0.8168 - val_loss: 0.2464 - val_accuracy: 0.8955
# Epoch 39/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.3460 - accuracy: 0.8337 - val_loss: 0.2438 - val_accuracy: 0.8731
# Epoch 40/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.3344 - accuracy: 0.8442 - val_loss: 0.2384 - val_accuracy: 0.8955
# Epoch 41/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.3706 - accuracy: 0.8063 - val_loss: 0.2353 - val_accuracy: 0.9030
# Epoch 42/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.3453 - accuracy: 0.8126 - val_loss: 0.2411 - val_accuracy: 0.8955
# Epoch 43/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.3412 - accuracy: 0.8316 - val_loss: 0.2427 - val_accuracy: 0.8806
# Epoch 44/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.3386 - accuracy: 0.8463 - val_loss: 0.2278 - val_accuracy: 0.8806
# Epoch 45/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.3610 - accuracy: 0.8147 - val_loss: 0.2368 - val_accuracy: 0.8806
# Epoch 46/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.3460 - accuracy: 0.8442 - val_loss: 0.2446 - val_accuracy: 0.8806
# Epoch 47/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.3261 - accuracy: 0.8358 - val_loss: 0.2476 - val_accuracy: 0.8806
# Epoch 48/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.3609 - accuracy: 0.8211 - val_loss: 0.2245 - val_accuracy: 0.9030
# Epoch 49/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.3450 - accuracy: 0.8232 - val_loss: 0.2517 - val_accuracy: 0.8881
# Epoch 50/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.3131 - accuracy: 0.8379 - val_loss: 0.2568 - val_accuracy: 0.8881
# Epoch 51/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.3385 - accuracy: 0.8400 - val_loss: 0.2182 - val_accuracy: 0.9179
# Epoch 52/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.3498 - accuracy: 0.8337 - val_loss: 0.2336 - val_accuracy: 0.9104
# Epoch 53/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.3494 - accuracy: 0.8232 - val_loss: 0.2365 - val_accuracy: 0.8657
# Epoch 54/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.3444 - accuracy: 0.8232 - val_loss: 0.2188 - val_accuracy: 0.9030
# Epoch 55/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.3239 - accuracy: 0.8674 - val_loss: 0.2176 - val_accuracy: 0.8881
# Epoch 56/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.3257 - accuracy: 0.8505 - val_loss: 0.2377 - val_accuracy: 0.8955
# Epoch 57/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.3006 - accuracy: 0.8632 - val_loss: 0.2356 - val_accuracy: 0.8955
# Epoch 58/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.3177 - accuracy: 0.8505 - val_loss: 0.2182 - val_accuracy: 0.9104
# Epoch 59/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.3321 - accuracy: 0.8232 - val_loss: 0.2282 - val_accuracy: 0.8507
# Epoch 60/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.3280 - accuracy: 0.8653 - val_loss: 0.2135 - val_accuracy: 0.8806
# Epoch 61/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.3230 - accuracy: 0.8400 - val_loss: 0.2296 - val_accuracy: 0.8582
# Epoch 62/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.3293 - accuracy: 0.8484 - val_loss: 0.2214 - val_accuracy: 0.8955
# Epoch 63/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.3244 - accuracy: 0.8463 - val_loss: 0.2323 - val_accuracy: 0.9030
# Epoch 64/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.3006 - accuracy: 0.8632 - val_loss: 0.2208 - val_accuracy: 0.9030
# Epoch 65/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.3255 - accuracy: 0.8484 - val_loss: 0.2143 - val_accuracy: 0.8806
# Epoch 66/100
# 15/15 [==============================] - 0s 25ms/step - loss: 0.3203 - accuracy: 0.8674 - val_loss: 0.2341 - val_accuracy: 0.8881
# Epoch 67/100
# 15/15 [==============================] - 0s 25ms/step - loss: 0.3090 - accuracy: 0.8442 - val_loss: 0.2453 - val_accuracy: 0.8955
# Epoch 68/100
# 15/15 [==============================] - 0s 28ms/step - loss: 0.2968 - accuracy: 0.8632 - val_loss: 0.2501 - val_accuracy: 0.9104
# Epoch 69/100
# 15/15 [==============================] - 0s 26ms/step - loss: 0.3203 - accuracy: 0.8400 - val_loss: 0.2335 - val_accuracy: 0.9179
# Epoch 70/100
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2852 - accuracy: 0.8571Restoring model weights from the end of the best epoch: 60.
# 15/15 [==============================] - 0s 28ms/step - loss: 0.2891 - accuracy: 0.8589 - val_loss: 0.2354 - val_accuracy: 0.9104
# Epoch 70: early stopping
# 5/5 [==============================] - 0s 4ms/step
# Accuracy: 0.8805970149253731
# Recall: [0.9375     0.59090909]
# Macro-averaged One-vs-Rest ROC AUC score:
# 0.945211038961039

# %%
import numpy as np
from sklearn.model_selection import KFold
from sklearn.model_selection import GroupKFold


num_classes = y_train.nunique()
num_folds = 5

# Split the dataset into features (X) and target (y)
X = combined_df.drop(['hf_type', 'study_id', 'subject_id', 'sex', 'nrg_lin_scgk', 'nrg_rot_scgk', 'pwr_lin_scgk', 'pwr_rot_scgk', 'rsp'], axis=1)
y = combined_df['hf_type']


# One-hot encode the target variables
y_cat = to_categorical(y)

# Define a function to create and return the model
def create_model():

    # Define the model architecture
    model = Sequential()

    # Add the first convolutional block
    model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(max_length, 1)))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))

    # Add the second convolutional block
    model.add(Conv1D(filters=16, kernel_size=3, activation='relu'))
    model.add(Dropout(rate=0.5))
    model.add(MaxPooling1D(pool_size=2))

    # Add the third convolutional block
    model.add(Conv1D(filters=16, kernel_size=3, activation='relu'))
    model.add(Dropout(rate=0.5))

    # Flatten the output of the convolutional blocks
    model.add(Flatten())

    # Add the fully connected layers
    model.add(Dense(units=1000, activation='relu'))
    model.add(Dropout(rate=0.5))
    model.add(Dense(units=1000, activation='relu'))
    model.add(Dropout(rate=0.5))

    # Add the output layer with Softmax activation function
    model.add(Dense(units=2, activation='softmax'))

    # Compile the model with categorical crossentropy loss
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
              
    return model

# Initialize the GroupKFold cross-validator
num_folds = 5
group_kfold = GroupKFold(n_splits=num_folds)

# Initialize variables to store evaluation metrics
accuracies = []
recalls = []
roc_aucs = []

# Iterate through the folds
for train_idx, val_idx in group_kfold.split(X, y, groups):
    # Split the dataset into training and validation sets for the current fold
    X_train_fold, X_val_fold = X.iloc[train_idx], X.iloc[val_idx]
    y_train_fold, y_val_fold = y.iloc[train_idx], y.iloc[val_idx]

    # Standardize the input features
    scaler = StandardScaler()
    X_train_fold = scaler.fit_transform(X_train_fold)
    X_val_fold = scaler.transform(X_val_fold)

    # One-hot encode the target variable
    #y_train_fold_enc = encoder.transform(y_train_fold)
    #y_val_fold_enc = encoder.transform(y_val_fold)
    y_train_fold_cat = to_categorical(y_train_fold)
    y_val_fold_cat = to_categorical(y_val_fold)

    # Reshape the input features to fit the 1D CNN model
    X_train_fold = X_train_fold.reshape((X_train_fold.shape[0], max_length, 1))
    X_val_fold = X_val_fold.reshape((X_val_fold.shape[0], max_length, 1))

    # Create a new model for each fold
    model = create_model()

    # Train the model on the current fold
    model.fit(X_train_fold, y_train_fold_cat, epochs=100, validation_data=(X_val_fold, y_val_fold_cat), callbacks=[early_stopping], verbose=2)

    # Evaluate the model on the validation set
    y_pred_cat = model.predict(X_val_fold)
    y_pred = np.argmax(y_pred_cat, axis=1)
    accuracy = accuracy_score(y_val_fold, y_pred)
    accuracies.append(accuracy)

    recall = recall_score(y_val_fold, y_pred, average=None)
    recalls.append(recall)

    roc_auc = roc_auc_score(y_val_fold_cat, y_pred_cat)

    roc_aucs.append(roc_auc)

# Calculate and print mean and standard deviation of evaluation metrics
mean_accuracy = np.mean(accuracies)
std_accuracy = np.std(accuracies)
mean_recall = np.mean(recalls, axis=0)
std_recall = np.std(recalls, axis=0)
mean_roc_auc = np.mean(roc_aucs)
std_roc_auc = np.std(roc_aucs)

print(f"\nMean accuracy: {mean_accuracy:.4f}, Standard deviation: {std_accuracy:.4f}")
print(f"\nMean recall: {mean_recall}, Standard deviation: {std_recall}")
print(f"\nMean ROC AUC: {mean_roc_auc:.4f}, Standard deviation: {std_roc_auc:.4f}")
# Out:
# Epoch 1/100
# 16/16 - 2s - loss: 0.9471 - accuracy: 0.7166 - val_loss: 0.6571 - val_accuracy: 0.7787 - 2s/epoch - 155ms/step
# Epoch 2/100
# 16/16 - 0s - loss: 0.6456 - accuracy: 0.7392 - val_loss: 0.6427 - val_accuracy: 0.8443 - 373ms/epoch - 23ms/step
# Epoch 3/100
# 16/16 - 0s - loss: 0.5577 - accuracy: 0.7864 - val_loss: 0.6091 - val_accuracy: 0.8197 - 377ms/epoch - 24ms/step
# Epoch 4/100
# 16/16 - 0s - loss: 0.5120 - accuracy: 0.7700 - val_loss: 0.6155 - val_accuracy: 0.8115 - 353ms/epoch - 22ms/step
# Epoch 5/100
# 16/16 - 0s - loss: 0.5273 - accuracy: 0.7639 - val_loss: 0.5968 - val_accuracy: 0.7787 - 356ms/epoch - 22ms/step
# Epoch 6/100
# 16/16 - 0s - loss: 0.4597 - accuracy: 0.7906 - val_loss: 0.5843 - val_accuracy: 0.7951 - 356ms/epoch - 22ms/step
# Epoch 7/100
# 16/16 - 0s - loss: 0.4929 - accuracy: 0.7659 - val_loss: 0.5763 - val_accuracy: 0.7951 - 355ms/epoch - 22ms/step
# Epoch 8/100
# 16/16 - 0s - loss: 0.4640 - accuracy: 0.7844 - val_loss: 0.5665 - val_accuracy: 0.7951 - 355ms/epoch - 22ms/step
# Epoch 9/100
# 16/16 - 0s - loss: 0.4204 - accuracy: 0.8111 - val_loss: 0.5557 - val_accuracy: 0.8115 - 353ms/epoch - 22ms/step
# Epoch 10/100
# 16/16 - 0s - loss: 0.4650 - accuracy: 0.7988 - val_loss: 0.5605 - val_accuracy: 0.7951 - 351ms/epoch - 22ms/step
# Epoch 11/100
# 16/16 - 0s - loss: 0.4542 - accuracy: 0.7598 - val_loss: 0.5203 - val_accuracy: 0.7951 - 353ms/epoch - 22ms/step
# Epoch 12/100
# 16/16 - 0s - loss: 0.4175 - accuracy: 0.8070 - val_loss: 0.4899 - val_accuracy: 0.7951 - 352ms/epoch - 22ms/step
# Epoch 13/100
# 16/16 - 0s - loss: 0.4216 - accuracy: 0.7844 - val_loss: 0.4576 - val_accuracy: 0.8115 - 351ms/epoch - 22ms/step
# Epoch 14/100
# 16/16 - 0s - loss: 0.3740 - accuracy: 0.8255 - val_loss: 0.4450 - val_accuracy: 0.8197 - 348ms/epoch - 22ms/step
# Epoch 15/100
# 16/16 - 0s - loss: 0.4047 - accuracy: 0.8214 - val_loss: 0.4309 - val_accuracy: 0.8033 - 351ms/epoch - 22ms/step
# Epoch 16/100
# 16/16 - 0s - loss: 0.3932 - accuracy: 0.7803 - val_loss: 0.4089 - val_accuracy: 0.8361 - 352ms/epoch - 22ms/step
# Epoch 17/100
# 16/16 - 0s - loss: 0.3906 - accuracy: 0.8090 - val_loss: 0.3863 - val_accuracy: 0.8443 - 352ms/epoch - 22ms/step
# Epoch 18/100
# 16/16 - 0s - loss: 0.4269 - accuracy: 0.7988 - val_loss: 0.4166 - val_accuracy: 0.8443 - 345ms/epoch - 22ms/step
# Epoch 19/100
# 16/16 - 0s - loss: 0.3559 - accuracy: 0.8419 - val_loss: 0.3620 - val_accuracy: 0.8197 - 351ms/epoch - 22ms/step
# Epoch 20/100
# 16/16 - 0s - loss: 0.3878 - accuracy: 0.8070 - val_loss: 0.3509 - val_accuracy: 0.8607 - 353ms/epoch - 22ms/step
# Epoch 21/100
# 16/16 - 0s - loss: 0.3624 - accuracy: 0.8316 - val_loss: 0.3452 - val_accuracy: 0.8525 - 362ms/epoch - 23ms/step
# Epoch 22/100
# 16/16 - 0s - loss: 0.3671 - accuracy: 0.8008 - val_loss: 0.3607 - val_accuracy: 0.8033 - 372ms/epoch - 23ms/step
# Epoch 23/100
# 16/16 - 0s - loss: 0.3400 - accuracy: 0.8172 - val_loss: 0.3361 - val_accuracy: 0.8361 - 367ms/epoch - 23ms/step
# Epoch 24/100
# 16/16 - 0s - loss: 0.3325 - accuracy: 0.8398 - val_loss: 0.3253 - val_accuracy: 0.8279 - 369ms/epoch - 23ms/step
# Epoch 25/100
# 16/16 - 0s - loss: 0.3159 - accuracy: 0.8542 - val_loss: 0.3157 - val_accuracy: 0.8361 - 381ms/epoch - 24ms/step
# Epoch 26/100
# 16/16 - 0s - loss: 0.3978 - accuracy: 0.8152 - val_loss: 0.3277 - val_accuracy: 0.8279 - 360ms/epoch - 22ms/step
# Epoch 27/100
# 16/16 - 0s - loss: 0.3431 - accuracy: 0.8193 - val_loss: 0.3130 - val_accuracy: 0.8607 - 383ms/epoch - 24ms/step
# Epoch 28/100
# 16/16 - 0s - loss: 0.3226 - accuracy: 0.8398 - val_loss: 0.3009 - val_accuracy: 0.8689 - 364ms/epoch - 23ms/step
# Epoch 29/100
# 16/16 - 0s - loss: 0.3253 - accuracy: 0.8316 - val_loss: 0.2975 - val_accuracy: 0.8361 - 352ms/epoch - 22ms/step
# Epoch 30/100
# 16/16 - 0s - loss: 0.3094 - accuracy: 0.8378 - val_loss: 0.3073 - val_accuracy: 0.8689 - 349ms/epoch - 22ms/step
# Epoch 31/100
# 16/16 - 0s - loss: 0.3120 - accuracy: 0.8522 - val_loss: 0.2932 - val_accuracy: 0.8852 - 358ms/epoch - 22ms/step
# Epoch 32/100
# 16/16 - 0s - loss: 0.3101 - accuracy: 0.8460 - val_loss: 0.2979 - val_accuracy: 0.8361 - 352ms/epoch - 22ms/step
# Epoch 33/100
# 16/16 - 0s - loss: 0.3111 - accuracy: 0.8460 - val_loss: 0.2969 - val_accuracy: 0.8443 - 352ms/epoch - 22ms/step
# Epoch 34/100
# 16/16 - 0s - loss: 0.3016 - accuracy: 0.8501 - val_loss: 0.3117 - val_accuracy: 0.8361 - 350ms/epoch - 22ms/step
# Epoch 35/100
# 16/16 - 0s - loss: 0.3571 - accuracy: 0.8090 - val_loss: 0.3104 - val_accuracy: 0.8279 - 352ms/epoch - 22ms/step
# Epoch 36/100
# 16/16 - 0s - loss: 0.2943 - accuracy: 0.8439 - val_loss: 0.3073 - val_accuracy: 0.8279 - 349ms/epoch - 22ms/step
# Epoch 37/100
# 16/16 - 0s - loss: 0.3115 - accuracy: 0.8419 - val_loss: 0.3314 - val_accuracy: 0.8361 - 350ms/epoch - 22ms/step
# Epoch 38/100
# 16/16 - 0s - loss: 0.3174 - accuracy: 0.8604 - val_loss: 0.3314 - val_accuracy: 0.8607 - 353ms/epoch - 22ms/step
# Epoch 39/100
# 16/16 - 0s - loss: 0.2860 - accuracy: 0.8522 - val_loss: 0.3229 - val_accuracy: 0.8361 - 350ms/epoch - 22ms/step
# Epoch 40/100
# 16/16 - 0s - loss: 0.2866 - accuracy: 0.8665 - val_loss: 0.3562 - val_accuracy: 0.8852 - 352ms/epoch - 22ms/step
# Epoch 41/100
# Restoring model weights from the end of the best epoch: 31.
# 16/16 - 0s - loss: 0.3059 - accuracy: 0.8604 - val_loss: 0.3441 - val_accuracy: 0.8361 - 363ms/epoch - 23ms/step
# Epoch 41: early stopping
# 4/4 [==============================] - 0s 4ms/step
# Epoch 1/100
# 16/16 - 3s - loss: 1.4387 - accuracy: 0.6982 - val_loss: 0.6883 - val_accuracy: 0.5984 - 3s/epoch - 180ms/step
# Epoch 2/100
# 16/16 - 0s - loss: 0.7258 - accuracy: 0.7269 - val_loss: 0.6504 - val_accuracy: 0.7869 - 351ms/epoch - 22ms/step
# Epoch 3/100
# 16/16 - 0s - loss: 0.6294 - accuracy: 0.7515 - val_loss: 0.6356 - val_accuracy: 0.7869 - 369ms/epoch - 23ms/step
# Epoch 4/100
# 16/16 - 0s - loss: 0.5231 - accuracy: 0.7556 - val_loss: 0.6138 - val_accuracy: 0.7869 - 379ms/epoch - 24ms/step
# Epoch 5/100
# 16/16 - 0s - loss: 0.4888 - accuracy: 0.7906 - val_loss: 0.6198 - val_accuracy: 0.7787 - 372ms/epoch - 23ms/step
# Epoch 6/100
# 16/16 - 0s - loss: 0.4979 - accuracy: 0.7782 - val_loss: 0.5972 - val_accuracy: 0.7869 - 375ms/epoch - 23ms/step
# Epoch 7/100
# 16/16 - 0s - loss: 0.4461 - accuracy: 0.8111 - val_loss: 0.5924 - val_accuracy: 0.7869 - 377ms/epoch - 24ms/step
# Epoch 8/100
# 16/16 - 0s - loss: 0.4707 - accuracy: 0.7721 - val_loss: 0.5933 - val_accuracy: 0.7869 - 381ms/epoch - 24ms/step
# Epoch 9/100
# 16/16 - 0s - loss: 0.4555 - accuracy: 0.7864 - val_loss: 0.5527 - val_accuracy: 0.7869 - 374ms/epoch - 23ms/step
# Epoch 10/100
# 16/16 - 0s - loss: 0.4179 - accuracy: 0.8111 - val_loss: 0.5557 - val_accuracy: 0.7869 - 383ms/epoch - 24ms/step
# Epoch 11/100
# 16/16 - 0s - loss: 0.4277 - accuracy: 0.7947 - val_loss: 0.5484 - val_accuracy: 0.7869 - 404ms/epoch - 25ms/step
# Epoch 12/100
# 16/16 - 0s - loss: 0.4000 - accuracy: 0.8255 - val_loss: 0.5297 - val_accuracy: 0.7869 - 397ms/epoch - 25ms/step
# Epoch 13/100
# 16/16 - 0s - loss: 0.4230 - accuracy: 0.8357 - val_loss: 0.5182 - val_accuracy: 0.7869 - 387ms/epoch - 24ms/step
# Epoch 14/100
# 16/16 - 0s - loss: 0.4153 - accuracy: 0.8049 - val_loss: 0.5021 - val_accuracy: 0.7869 - 378ms/epoch - 24ms/step
# Epoch 15/100
# 16/16 - 0s - loss: 0.3755 - accuracy: 0.8070 - val_loss: 0.4750 - val_accuracy: 0.7869 - 395ms/epoch - 25ms/step
# Epoch 16/100
# 16/16 - 0s - loss: 0.3902 - accuracy: 0.8049 - val_loss: 0.4735 - val_accuracy: 0.7787 - 381ms/epoch - 24ms/step
# Epoch 17/100
# 16/16 - 0s - loss: 0.3891 - accuracy: 0.8214 - val_loss: 0.4366 - val_accuracy: 0.7869 - 396ms/epoch - 25ms/step
# Epoch 18/100
# 16/16 - 0s - loss: 0.3669 - accuracy: 0.8090 - val_loss: 0.4390 - val_accuracy: 0.7869 - 368ms/epoch - 23ms/step
# Epoch 19/100
# 16/16 - 0s - loss: 0.3583 - accuracy: 0.8152 - val_loss: 0.4216 - val_accuracy: 0.7869 - 401ms/epoch - 25ms/step
# Epoch 20/100
# 16/16 - 0s - loss: 0.3442 - accuracy: 0.8480 - val_loss: 0.4052 - val_accuracy: 0.8033 - 376ms/epoch - 24ms/step
# Epoch 21/100
# 16/16 - 0s - loss: 0.3569 - accuracy: 0.8255 - val_loss: 0.3887 - val_accuracy: 0.8033 - 387ms/epoch - 24ms/step
# Epoch 22/100
# 16/16 - 0s - loss: 0.3631 - accuracy: 0.8378 - val_loss: 0.4180 - val_accuracy: 0.8115 - 405ms/epoch - 25ms/step
# Epoch 23/100
# 16/16 - 0s - loss: 0.3453 - accuracy: 0.8193 - val_loss: 0.3853 - val_accuracy: 0.8115 - 360ms/epoch - 22ms/step
# Epoch 24/100
# 16/16 - 0s - loss: 0.3547 - accuracy: 0.8214 - val_loss: 0.3757 - val_accuracy: 0.8115 - 360ms/epoch - 22ms/step
# Epoch 25/100
# 16/16 - 0s - loss: 0.3502 - accuracy: 0.8131 - val_loss: 0.3853 - val_accuracy: 0.8033 - 348ms/epoch - 22ms/step
# Epoch 26/100
# 16/16 - 0s - loss: 0.3400 - accuracy: 0.8357 - val_loss: 0.3762 - val_accuracy: 0.7869 - 348ms/epoch - 22ms/step
# Epoch 27/100
# 16/16 - 0s - loss: 0.3307 - accuracy: 0.8439 - val_loss: 0.3749 - val_accuracy: 0.8197 - 367ms/epoch - 23ms/step
# Epoch 28/100
# 16/16 - 0s - loss: 0.3334 - accuracy: 0.8357 - val_loss: 0.3666 - val_accuracy: 0.8443 - 352ms/epoch - 22ms/step
# Epoch 29/100
# 16/16 - 0s - loss: 0.3288 - accuracy: 0.8563 - val_loss: 0.3495 - val_accuracy: 0.8197 - 355ms/epoch - 22ms/step
# Epoch 30/100
# 16/16 - 0s - loss: 0.3395 - accuracy: 0.8255 - val_loss: 0.3693 - val_accuracy: 0.8525 - 343ms/epoch - 21ms/step
# Epoch 31/100
# 16/16 - 0s - loss: 0.3302 - accuracy: 0.8542 - val_loss: 0.3651 - val_accuracy: 0.8361 - 348ms/epoch - 22ms/step
# Epoch 32/100
# 16/16 - 0s - loss: 0.3232 - accuracy: 0.8480 - val_loss: 0.3427 - val_accuracy: 0.7951 - 402ms/epoch - 25ms/step
# Epoch 33/100
# 16/16 - 0s - loss: 0.3245 - accuracy: 0.8378 - val_loss: 0.3573 - val_accuracy: 0.8443 - 357ms/epoch - 22ms/step
# Epoch 34/100
# 16/16 - 0s - loss: 0.3141 - accuracy: 0.8604 - val_loss: 0.3390 - val_accuracy: 0.8443 - 364ms/epoch - 23ms/step
# Epoch 35/100
# 16/16 - 0s - loss: 0.3062 - accuracy: 0.8460 - val_loss: 0.3504 - val_accuracy: 0.8689 - 353ms/epoch - 22ms/step
# Epoch 36/100
# 16/16 - 0s - loss: 0.3178 - accuracy: 0.8522 - val_loss: 0.3596 - val_accuracy: 0.8770 - 363ms/epoch - 23ms/step
# Epoch 37/100
# 16/16 - 0s - loss: 0.3146 - accuracy: 0.8398 - val_loss: 0.3533 - val_accuracy: 0.8443 - 395ms/epoch - 25ms/step
# Epoch 38/100
# 16/16 - 0s - loss: 0.2988 - accuracy: 0.8583 - val_loss: 0.3599 - val_accuracy: 0.8525 - 416ms/epoch - 26ms/step
# Epoch 39/100
# 16/16 - 0s - loss: 0.3122 - accuracy: 0.8460 - val_loss: 0.3470 - val_accuracy: 0.8770 - 377ms/epoch - 24ms/step
# Epoch 40/100
# 16/16 - 0s - loss: 0.3273 - accuracy: 0.8357 - val_loss: 0.3392 - val_accuracy: 0.8689 - 396ms/epoch - 25ms/step
# Epoch 41/100
# 16/16 - 0s - loss: 0.2854 - accuracy: 0.8706 - val_loss: 0.3444 - val_accuracy: 0.8525 - 357ms/epoch - 22ms/step
# Epoch 42/100
# 16/16 - 0s - loss: 0.2731 - accuracy: 0.8563 - val_loss: 0.3389 - val_accuracy: 0.8689 - 385ms/epoch - 24ms/step
# Epoch 43/100
# 16/16 - 0s - loss: 0.2817 - accuracy: 0.8665 - val_loss: 0.3555 - val_accuracy: 0.8525 - 366ms/epoch - 23ms/step
# Epoch 44/100
# 16/16 - 0s - loss: 0.2999 - accuracy: 0.8583 - val_loss: 0.3455 - val_accuracy: 0.8443 - 351ms/epoch - 22ms/step
# Epoch 45/100
# 16/16 - 0s - loss: 0.2878 - accuracy: 0.8830 - val_loss: 0.3734 - val_accuracy: 0.8689 - 351ms/epoch - 22ms/step
# Epoch 46/100
# 16/16 - 0s - loss: 0.2747 - accuracy: 0.8686 - val_loss: 0.3776 - val_accuracy: 0.8607 - 352ms/epoch - 22ms/step
# Epoch 47/100
# 16/16 - 0s - loss: 0.2863 - accuracy: 0.8789 - val_loss: 0.3611 - val_accuracy: 0.8525 - 348ms/epoch - 22ms/step
# Epoch 48/100
# 16/16 - 0s - loss: 0.2888 - accuracy: 0.8624 - val_loss: 0.3450 - val_accuracy: 0.8689 - 348ms/epoch - 22ms/step
# Epoch 49/100
# 16/16 - 0s - loss: 0.2750 - accuracy: 0.8686 - val_loss: 0.3566 - val_accuracy: 0.8607 - 350ms/epoch - 22ms/step
# Epoch 50/100
# 16/16 - 0s - loss: 0.3210 - accuracy: 0.8522 - val_loss: 0.3405 - val_accuracy: 0.8689 - 348ms/epoch - 22ms/step
# Epoch 51/100
# 16/16 - 0s - loss: 0.3131 - accuracy: 0.8337 - val_loss: 0.3574 - val_accuracy: 0.8852 - 347ms/epoch - 22ms/step
# Epoch 52/100
# Restoring model weights from the end of the best epoch: 42.
# 16/16 - 0s - loss: 0.2769 - accuracy: 0.8830 - val_loss: 0.3450 - val_accuracy: 0.8443 - 356ms/epoch - 22ms/step
# Epoch 52: early stopping
# 4/4 [==============================] - 0s 5ms/step
# Epoch 1/100
# 16/16 - 3s - loss: 0.8672 - accuracy: 0.7125 - val_loss: 0.6561 - val_accuracy: 0.7541 - 3s/epoch - 168ms/step
# Epoch 2/100
# 16/16 - 0s - loss: 0.6205 - accuracy: 0.7228 - val_loss: 0.6200 - val_accuracy: 0.7869 - 368ms/epoch - 23ms/step
# Epoch 3/100
# 16/16 - 0s - loss: 0.5740 - accuracy: 0.7823 - val_loss: 0.6020 - val_accuracy: 0.7623 - 380ms/epoch - 24ms/step
# Epoch 4/100
# 16/16 - 0s - loss: 0.5444 - accuracy: 0.7844 - val_loss: 0.5966 - val_accuracy: 0.7623 - 391ms/epoch - 24ms/step
# Epoch 5/100
# 16/16 - 0s - loss: 0.4690 - accuracy: 0.8070 - val_loss: 0.5839 - val_accuracy: 0.7787 - 375ms/epoch - 23ms/step
# Epoch 6/100
# 16/16 - 0s - loss: 0.4721 - accuracy: 0.7885 - val_loss: 0.5829 - val_accuracy: 0.7705 - 363ms/epoch - 23ms/step
# Epoch 7/100
# 16/16 - 0s - loss: 0.4642 - accuracy: 0.7926 - val_loss: 0.5621 - val_accuracy: 0.7623 - 371ms/epoch - 23ms/step
# Epoch 8/100
# 16/16 - 0s - loss: 0.4440 - accuracy: 0.7988 - val_loss: 0.5565 - val_accuracy: 0.7623 - 362ms/epoch - 23ms/step
# Epoch 9/100
# 16/16 - 0s - loss: 0.4424 - accuracy: 0.7988 - val_loss: 0.5301 - val_accuracy: 0.7623 - 353ms/epoch - 22ms/step
# Epoch 10/100
# 16/16 - 0s - loss: 0.4775 - accuracy: 0.7598 - val_loss: 0.5354 - val_accuracy: 0.7623 - 355ms/epoch - 22ms/step
# Epoch 11/100
# 16/16 - 0s - loss: 0.4017 - accuracy: 0.8172 - val_loss: 0.5121 - val_accuracy: 0.7705 - 358ms/epoch - 22ms/step
# Epoch 12/100
# 16/16 - 0s - loss: 0.3958 - accuracy: 0.7967 - val_loss: 0.4719 - val_accuracy: 0.7787 - 356ms/epoch - 22ms/step
# Epoch 13/100
# 16/16 - 0s - loss: 0.4207 - accuracy: 0.8008 - val_loss: 0.4674 - val_accuracy: 0.7787 - 352ms/epoch - 22ms/step
# Epoch 14/100
# 16/16 - 0s - loss: 0.3950 - accuracy: 0.8111 - val_loss: 0.4447 - val_accuracy: 0.7787 - 352ms/epoch - 22ms/step
# Epoch 15/100
# 16/16 - 0s - loss: 0.4095 - accuracy: 0.8008 - val_loss: 0.4398 - val_accuracy: 0.7787 - 406ms/epoch - 25ms/step
# Epoch 16/100
# 16/16 - 0s - loss: 0.3698 - accuracy: 0.8234 - val_loss: 0.4215 - val_accuracy: 0.7787 - 382ms/epoch - 24ms/step
# Epoch 17/100
# 16/16 - 0s - loss: 0.3540 - accuracy: 0.8275 - val_loss: 0.4086 - val_accuracy: 0.7787 - 394ms/epoch - 25ms/step
# Epoch 18/100
# 16/16 - 0s - loss: 0.3887 - accuracy: 0.8008 - val_loss: 0.4029 - val_accuracy: 0.7787 - 380ms/epoch - 24ms/step
# Epoch 19/100
# 16/16 - 0s - loss: 0.3541 - accuracy: 0.8337 - val_loss: 0.3872 - val_accuracy: 0.7787 - 354ms/epoch - 22ms/step
# Epoch 20/100
# 16/16 - 0s - loss: 0.3650 - accuracy: 0.8255 - val_loss: 0.3883 - val_accuracy: 0.7787 - 390ms/epoch - 24ms/step
# Epoch 21/100
# 16/16 - 0s - loss: 0.3608 - accuracy: 0.8357 - val_loss: 0.3824 - val_accuracy: 0.7787 - 415ms/epoch - 26ms/step
# Epoch 22/100
# 16/16 - 0s - loss: 0.3437 - accuracy: 0.8419 - val_loss: 0.3648 - val_accuracy: 0.7787 - 362ms/epoch - 23ms/step
# Epoch 23/100
# 16/16 - 0s - loss: 0.3416 - accuracy: 0.8480 - val_loss: 0.3570 - val_accuracy: 0.7787 - 384ms/epoch - 24ms/step
# Epoch 24/100
# 16/16 - 0s - loss: 0.3270 - accuracy: 0.8460 - val_loss: 0.3375 - val_accuracy: 0.8033 - 356ms/epoch - 22ms/step
# Epoch 25/100
# 16/16 - 0s - loss: 0.3281 - accuracy: 0.8645 - val_loss: 0.3294 - val_accuracy: 0.8033 - 375ms/epoch - 23ms/step
# Epoch 26/100
# 16/16 - 0s - loss: 0.3345 - accuracy: 0.8439 - val_loss: 0.3388 - val_accuracy: 0.8115 - 356ms/epoch - 22ms/step
# Epoch 27/100
# 16/16 - 0s - loss: 0.3399 - accuracy: 0.8193 - val_loss: 0.3349 - val_accuracy: 0.7951 - 377ms/epoch - 24ms/step
# Epoch 28/100
# 16/16 - 0s - loss: 0.3337 - accuracy: 0.8460 - val_loss: 0.3279 - val_accuracy: 0.8115 - 405ms/epoch - 25ms/step
# Epoch 29/100
# 16/16 - 0s - loss: 0.3274 - accuracy: 0.8439 - val_loss: 0.3133 - val_accuracy: 0.8279 - 379ms/epoch - 24ms/step
# Epoch 30/100
# 16/16 - 0s - loss: 0.3396 - accuracy: 0.8357 - val_loss: 0.3203 - val_accuracy: 0.8197 - 368ms/epoch - 23ms/step
# Epoch 31/100
# 16/16 - 0s - loss: 0.3133 - accuracy: 0.8747 - val_loss: 0.3067 - val_accuracy: 0.8279 - 398ms/epoch - 25ms/step
# Epoch 32/100
# 16/16 - 0s - loss: 0.3296 - accuracy: 0.8501 - val_loss: 0.3073 - val_accuracy: 0.8361 - 364ms/epoch - 23ms/step
# Epoch 33/100
# 16/16 - 0s - loss: 0.3260 - accuracy: 0.8480 - val_loss: 0.3208 - val_accuracy: 0.8279 - 383ms/epoch - 24ms/step
# Epoch 34/100
# 16/16 - 0s - loss: 0.3338 - accuracy: 0.8419 - val_loss: 0.3050 - val_accuracy: 0.8279 - 369ms/epoch - 23ms/step
# Epoch 35/100
# 16/16 - 0s - loss: 0.3248 - accuracy: 0.8337 - val_loss: 0.2968 - val_accuracy: 0.8361 - 378ms/epoch - 24ms/step
# Epoch 36/100
# 16/16 - 0s - loss: 0.3175 - accuracy: 0.8645 - val_loss: 0.3056 - val_accuracy: 0.8197 - 366ms/epoch - 23ms/step
# Epoch 37/100
# 16/16 - 0s - loss: 0.3443 - accuracy: 0.8255 - val_loss: 0.3078 - val_accuracy: 0.8361 - 381ms/epoch - 24ms/step
# Epoch 38/100
# 16/16 - 0s - loss: 0.3219 - accuracy: 0.8480 - val_loss: 0.3073 - val_accuracy: 0.8525 - 421ms/epoch - 26ms/step
# Epoch 39/100
# 16/16 - 0s - loss: 0.3172 - accuracy: 0.8419 - val_loss: 0.3030 - val_accuracy: 0.8279 - 373ms/epoch - 23ms/step
# Epoch 40/100
# 16/16 - 0s - loss: 0.3452 - accuracy: 0.8357 - val_loss: 0.3053 - val_accuracy: 0.8279 - 359ms/epoch - 22ms/step
# Epoch 41/100
# 16/16 - 0s - loss: 0.3269 - accuracy: 0.8501 - val_loss: 0.3105 - val_accuracy: 0.8443 - 368ms/epoch - 23ms/step
# Epoch 42/100
# 16/16 - 0s - loss: 0.3332 - accuracy: 0.8604 - val_loss: 0.2989 - val_accuracy: 0.8443 - 378ms/epoch - 24ms/step
# Epoch 43/100
# 16/16 - 0s - loss: 0.3018 - accuracy: 0.8542 - val_loss: 0.2848 - val_accuracy: 0.8689 - 398ms/epoch - 25ms/step
# Epoch 44/100
# 16/16 - 0s - loss: 0.3354 - accuracy: 0.8378 - val_loss: 0.3215 - val_accuracy: 0.8115 - 396ms/epoch - 25ms/step
# Epoch 45/100
# 16/16 - 0s - loss: 0.3168 - accuracy: 0.8645 - val_loss: 0.3098 - val_accuracy: 0.8361 - 369ms/epoch - 23ms/step
# Epoch 46/100
# 16/16 - 0s - loss: 0.3277 - accuracy: 0.8501 - val_loss: 0.2953 - val_accuracy: 0.8443 - 373ms/epoch - 23ms/step
# Epoch 47/100
# 16/16 - 0s - loss: 0.3071 - accuracy: 0.8583 - val_loss: 0.2902 - val_accuracy: 0.8279 - 374ms/epoch - 23ms/step
# Epoch 48/100
# 16/16 - 0s - loss: 0.3327 - accuracy: 0.8337 - val_loss: 0.3047 - val_accuracy: 0.8361 - 403ms/epoch - 25ms/step
# Epoch 49/100
# 16/16 - 0s - loss: 0.2914 - accuracy: 0.8542 - val_loss: 0.2875 - val_accuracy: 0.8689 - 382ms/epoch - 24ms/step
# Epoch 50/100
# 16/16 - 0s - loss: 0.3040 - accuracy: 0.8439 - val_loss: 0.2872 - val_accuracy: 0.8689 - 377ms/epoch - 24ms/step
# Epoch 51/100
# 16/16 - 0s - loss: 0.3017 - accuracy: 0.8665 - val_loss: 0.2962 - val_accuracy: 0.8279 - 359ms/epoch - 22ms/step
# Epoch 52/100
# 16/16 - 0s - loss: 0.2932 - accuracy: 0.8604 - val_loss: 0.2900 - val_accuracy: 0.8279 - 348ms/epoch - 22ms/step
# Epoch 53/100
# Restoring model weights from the end of the best epoch: 43.
# 16/16 - 0s - loss: 0.3092 - accuracy: 0.8665 - val_loss: 0.3021 - val_accuracy: 0.8279 - 351ms/epoch - 22ms/step
# Epoch 53: early stopping
# 4/4 [==============================] - 0s 4ms/step
# Epoch 1/100
# 16/16 - 3s - loss: 0.8765 - accuracy: 0.7207 - val_loss: 0.6443 - val_accuracy: 0.7787 - 3s/epoch - 191ms/step
# Epoch 2/100
# 16/16 - 0s - loss: 0.6671 - accuracy: 0.7639 - val_loss: 0.6186 - val_accuracy: 0.8197 - 374ms/epoch - 23ms/step
# Epoch 3/100
# 16/16 - 0s - loss: 0.6467 - accuracy: 0.7515 - val_loss: 0.6419 - val_accuracy: 0.8115 - 357ms/epoch - 22ms/step
# Epoch 4/100
# 16/16 - 0s - loss: 0.5188 - accuracy: 0.7680 - val_loss: 0.6064 - val_accuracy: 0.8115 - 367ms/epoch - 23ms/step
# Epoch 5/100
# 16/16 - 0s - loss: 0.4794 - accuracy: 0.8193 - val_loss: 0.6052 - val_accuracy: 0.8361 - 359ms/epoch - 22ms/step
# Epoch 6/100
# 16/16 - 0s - loss: 0.4732 - accuracy: 0.7885 - val_loss: 0.5943 - val_accuracy: 0.8197 - 361ms/epoch - 23ms/step
# Epoch 7/100
# 16/16 - 0s - loss: 0.4881 - accuracy: 0.7782 - val_loss: 0.5552 - val_accuracy: 0.8361 - 364ms/epoch - 23ms/step
# Epoch 8/100
# 16/16 - 0s - loss: 0.4668 - accuracy: 0.7885 - val_loss: 0.5470 - val_accuracy: 0.8361 - 363ms/epoch - 23ms/step
# Epoch 9/100
# 16/16 - 0s - loss: 0.4465 - accuracy: 0.7803 - val_loss: 0.5340 - val_accuracy: 0.8197 - 374ms/epoch - 23ms/step
# Epoch 10/100
# 16/16 - 0s - loss: 0.4297 - accuracy: 0.8070 - val_loss: 0.5351 - val_accuracy: 0.8197 - 384ms/epoch - 24ms/step
# Epoch 11/100
# 16/16 - 0s - loss: 0.4248 - accuracy: 0.8070 - val_loss: 0.5114 - val_accuracy: 0.8115 - 358ms/epoch - 22ms/step
# Epoch 12/100
# 16/16 - 0s - loss: 0.4193 - accuracy: 0.8214 - val_loss: 0.5204 - val_accuracy: 0.8033 - 356ms/epoch - 22ms/step
# Epoch 13/100
# 16/16 - 0s - loss: 0.3971 - accuracy: 0.8111 - val_loss: 0.4930 - val_accuracy: 0.8115 - 378ms/epoch - 24ms/step
# Epoch 14/100
# 16/16 - 0s - loss: 0.4150 - accuracy: 0.8049 - val_loss: 0.4702 - val_accuracy: 0.8361 - 399ms/epoch - 25ms/step
# Epoch 15/100
# 16/16 - 0s - loss: 0.3847 - accuracy: 0.8214 - val_loss: 0.4775 - val_accuracy: 0.8197 - 402ms/epoch - 25ms/step
# Epoch 16/100
# 16/16 - 0s - loss: 0.3808 - accuracy: 0.8275 - val_loss: 0.4404 - val_accuracy: 0.8115 - 393ms/epoch - 25ms/step
# Epoch 17/100
# 16/16 - 0s - loss: 0.3872 - accuracy: 0.8234 - val_loss: 0.4480 - val_accuracy: 0.8197 - 393ms/epoch - 25ms/step
# Epoch 18/100
# 16/16 - 0s - loss: 0.3640 - accuracy: 0.8296 - val_loss: 0.4074 - val_accuracy: 0.8033 - 397ms/epoch - 25ms/step
# Epoch 19/100
# 16/16 - 0s - loss: 0.3749 - accuracy: 0.8337 - val_loss: 0.4261 - val_accuracy: 0.8525 - 377ms/epoch - 24ms/step
# Epoch 20/100
# 16/16 - 0s - loss: 0.3461 - accuracy: 0.8337 - val_loss: 0.4005 - val_accuracy: 0.8279 - 372ms/epoch - 23ms/step
# Epoch 21/100
# 16/16 - 0s - loss: 0.3890 - accuracy: 0.7947 - val_loss: 0.3955 - val_accuracy: 0.8279 - 393ms/epoch - 25ms/step
# Epoch 22/100
# 16/16 - 0s - loss: 0.3553 - accuracy: 0.8193 - val_loss: 0.3837 - val_accuracy: 0.8197 - 381ms/epoch - 24ms/step
# Epoch 23/100
# 16/16 - 0s - loss: 0.3395 - accuracy: 0.8378 - val_loss: 0.3863 - val_accuracy: 0.8115 - 410ms/epoch - 26ms/step
# Epoch 24/100
# 16/16 - 0s - loss: 0.3255 - accuracy: 0.8316 - val_loss: 0.3598 - val_accuracy: 0.8361 - 427ms/epoch - 27ms/step
# Epoch 25/100
# 16/16 - 0s - loss: 0.3567 - accuracy: 0.8337 - val_loss: 0.3774 - val_accuracy: 0.8279 - 386ms/epoch - 24ms/step
# Epoch 26/100
# 16/16 - 0s - loss: 0.3710 - accuracy: 0.8214 - val_loss: 0.3484 - val_accuracy: 0.8361 - 388ms/epoch - 24ms/step
# Epoch 27/100
# 16/16 - 0s - loss: 0.3706 - accuracy: 0.8111 - val_loss: 0.3933 - val_accuracy: 0.8115 - 383ms/epoch - 24ms/step
# Epoch 28/100
# 16/16 - 0s - loss: 0.3723 - accuracy: 0.8419 - val_loss: 0.3401 - val_accuracy: 0.8115 - 387ms/epoch - 24ms/step
# Epoch 29/100
# 16/16 - 0s - loss: 0.3612 - accuracy: 0.8296 - val_loss: 0.3653 - val_accuracy: 0.8197 - 385ms/epoch - 24ms/step
# Epoch 30/100
# 16/16 - 0s - loss: 0.3413 - accuracy: 0.8193 - val_loss: 0.3385 - val_accuracy: 0.8361 - 362ms/epoch - 23ms/step
# Epoch 31/100
# 16/16 - 0s - loss: 0.3292 - accuracy: 0.8439 - val_loss: 0.3465 - val_accuracy: 0.8607 - 354ms/epoch - 22ms/step
# Epoch 32/100
# 16/16 - 0s - loss: 0.3374 - accuracy: 0.8275 - val_loss: 0.3436 - val_accuracy: 0.8689 - 359ms/epoch - 22ms/step
# Epoch 33/100
# 16/16 - 0s - loss: 0.3484 - accuracy: 0.8378 - val_loss: 0.3253 - val_accuracy: 0.8443 - 364ms/epoch - 23ms/step
# Epoch 34/100
# 16/16 - 0s - loss: 0.3270 - accuracy: 0.8460 - val_loss: 0.3561 - val_accuracy: 0.8361 - 353ms/epoch - 22ms/step
# Epoch 35/100
# 16/16 - 0s - loss: 0.3357 - accuracy: 0.8357 - val_loss: 0.3142 - val_accuracy: 0.8525 - 363ms/epoch - 23ms/step
# Epoch 36/100
# 16/16 - 0s - loss: 0.3187 - accuracy: 0.8480 - val_loss: 0.3267 - val_accuracy: 0.8525 - 360ms/epoch - 22ms/step
# Epoch 37/100
# 16/16 - 0s - loss: 0.3367 - accuracy: 0.8357 - val_loss: 0.3378 - val_accuracy: 0.8525 - 361ms/epoch - 23ms/step
# Epoch 38/100
# 16/16 - 0s - loss: 0.3125 - accuracy: 0.8460 - val_loss: 0.3407 - val_accuracy: 0.8361 - 360ms/epoch - 22ms/step
# Epoch 39/100
# 16/16 - 0s - loss: 0.3189 - accuracy: 0.8316 - val_loss: 0.3082 - val_accuracy: 0.8443 - 363ms/epoch - 23ms/step
# Epoch 40/100
# 16/16 - 0s - loss: 0.2962 - accuracy: 0.8583 - val_loss: 0.3186 - val_accuracy: 0.8443 - 352ms/epoch - 22ms/step
# Epoch 41/100
# 16/16 - 0s - loss: 0.3214 - accuracy: 0.8563 - val_loss: 0.2972 - val_accuracy: 0.8607 - 364ms/epoch - 23ms/step
# Epoch 42/100
# 16/16 - 0s - loss: 0.3196 - accuracy: 0.8439 - val_loss: 0.3160 - val_accuracy: 0.8770 - 361ms/epoch - 23ms/step
# Epoch 43/100
# 16/16 - 0s - loss: 0.3081 - accuracy: 0.8542 - val_loss: 0.3099 - val_accuracy: 0.8770 - 361ms/epoch - 23ms/step
# Epoch 44/100
# 16/16 - 0s - loss: 0.3158 - accuracy: 0.8275 - val_loss: 0.3218 - val_accuracy: 0.8443 - 366ms/epoch - 23ms/step
# Epoch 45/100
# 16/16 - 0s - loss: 0.3078 - accuracy: 0.8686 - val_loss: 0.3231 - val_accuracy: 0.8443 - 358ms/epoch - 22ms/step
# Epoch 46/100
# 16/16 - 0s - loss: 0.3256 - accuracy: 0.8583 - val_loss: 0.3237 - val_accuracy: 0.8525 - 356ms/epoch - 22ms/step
# Epoch 47/100
# 16/16 - 0s - loss: 0.2911 - accuracy: 0.8665 - val_loss: 0.3173 - val_accuracy: 0.8361 - 357ms/epoch - 22ms/step
# Epoch 48/100
# 16/16 - 0s - loss: 0.3426 - accuracy: 0.8563 - val_loss: 0.3165 - val_accuracy: 0.8934 - 356ms/epoch - 22ms/step
# Epoch 49/100
# 16/16 - 0s - loss: 0.2837 - accuracy: 0.8624 - val_loss: 0.3109 - val_accuracy: 0.8852 - 353ms/epoch - 22ms/step
# Epoch 50/100
# 16/16 - 0s - loss: 0.2998 - accuracy: 0.8604 - val_loss: 0.3140 - val_accuracy: 0.8525 - 359ms/epoch - 22ms/step
# Epoch 51/100
# Restoring model weights from the end of the best epoch: 41.
# 16/16 - 0s - loss: 0.3277 - accuracy: 0.8542 - val_loss: 0.3138 - val_accuracy: 0.8770 - 366ms/epoch - 23ms/step
# Epoch 51: early stopping
# 4/4 [==============================] - 0s 5ms/step
# Epoch 1/100
# 16/16 - 3s - loss: 1.0564 - accuracy: 0.7234 - val_loss: 0.7398 - val_accuracy: 0.7355 - 3s/epoch - 162ms/step
# Epoch 2/100
# 16/16 - 0s - loss: 0.5806 - accuracy: 0.7561 - val_loss: 0.7332 - val_accuracy: 0.8017 - 366ms/epoch - 23ms/step
# Epoch 3/100
# 16/16 - 0s - loss: 0.4861 - accuracy: 0.7766 - val_loss: 0.7686 - val_accuracy: 0.7603 - 357ms/epoch - 22ms/step
# Epoch 4/100
# 16/16 - 0s - loss: 0.4896 - accuracy: 0.8033 - val_loss: 0.7490 - val_accuracy: 0.7851 - 358ms/epoch - 22ms/step
# Epoch 5/100
# 16/16 - 0s - loss: 0.4906 - accuracy: 0.8012 - val_loss: 0.7182 - val_accuracy: 0.7769 - 374ms/epoch - 23ms/step
# Epoch 6/100
# 16/16 - 0s - loss: 0.4633 - accuracy: 0.8094 - val_loss: 0.6982 - val_accuracy: 0.7934 - 394ms/epoch - 25ms/step
# Epoch 7/100
# 16/16 - 0s - loss: 0.4505 - accuracy: 0.7910 - val_loss: 0.6946 - val_accuracy: 0.7769 - 415ms/epoch - 26ms/step
# Epoch 8/100
# 16/16 - 0s - loss: 0.4471 - accuracy: 0.8074 - val_loss: 0.6289 - val_accuracy: 0.7603 - 426ms/epoch - 27ms/step
# Epoch 9/100
# 16/16 - 0s - loss: 0.4225 - accuracy: 0.8197 - val_loss: 0.6396 - val_accuracy: 0.7603 - 395ms/epoch - 25ms/step
# Epoch 10/100
# 16/16 - 0s - loss: 0.4049 - accuracy: 0.8074 - val_loss: 0.6112 - val_accuracy: 0.7851 - 404ms/epoch - 25ms/step
# Epoch 11/100
# 16/16 - 0s - loss: 0.4292 - accuracy: 0.7992 - val_loss: 0.6077 - val_accuracy: 0.7851 - 390ms/epoch - 24ms/step
# Epoch 12/100
# 16/16 - 0s - loss: 0.3611 - accuracy: 0.8258 - val_loss: 0.5579 - val_accuracy: 0.8017 - 395ms/epoch - 25ms/step
# Epoch 13/100
# 16/16 - 0s - loss: 0.4137 - accuracy: 0.8053 - val_loss: 0.5488 - val_accuracy: 0.7851 - 441ms/epoch - 28ms/step
# Epoch 14/100
# 16/16 - 0s - loss: 0.3710 - accuracy: 0.8340 - val_loss: 0.5121 - val_accuracy: 0.8017 - 410ms/epoch - 26ms/step
# Epoch 15/100
# 16/16 - 0s - loss: 0.3556 - accuracy: 0.8381 - val_loss: 0.5341 - val_accuracy: 0.7934 - 399ms/epoch - 25ms/step
# Epoch 16/100
# 16/16 - 0s - loss: 0.3668 - accuracy: 0.8340 - val_loss: 0.5530 - val_accuracy: 0.8017 - 405ms/epoch - 25ms/step
# Epoch 17/100
# 16/16 - 0s - loss: 0.3591 - accuracy: 0.8463 - val_loss: 0.5184 - val_accuracy: 0.8017 - 395ms/epoch - 25ms/step
# Epoch 18/100
# 16/16 - 0s - loss: 0.3409 - accuracy: 0.8402 - val_loss: 0.4671 - val_accuracy: 0.8182 - 375ms/epoch - 23ms/step
# Epoch 19/100
# 16/16 - 0s - loss: 0.3431 - accuracy: 0.8340 - val_loss: 0.5161 - val_accuracy: 0.7851 - 374ms/epoch - 23ms/step
# Epoch 20/100
# 16/16 - 0s - loss: 0.3610 - accuracy: 0.8443 - val_loss: 0.4137 - val_accuracy: 0.8347 - 392ms/epoch - 24ms/step
# Epoch 21/100
# 16/16 - 0s - loss: 0.3456 - accuracy: 0.8258 - val_loss: 0.4875 - val_accuracy: 0.8099 - 382ms/epoch - 24ms/step
# Epoch 22/100
# 16/16 - 0s - loss: 0.3282 - accuracy: 0.8258 - val_loss: 0.4487 - val_accuracy: 0.8347 - 363ms/epoch - 23ms/step
# Epoch 23/100
# 16/16 - 0s - loss: 0.2995 - accuracy: 0.8545 - val_loss: 0.4782 - val_accuracy: 0.8595 - 412ms/epoch - 26ms/step
# Epoch 24/100
# 16/16 - 0s - loss: 0.3396 - accuracy: 0.8525 - val_loss: 0.3602 - val_accuracy: 0.8512 - 497ms/epoch - 31ms/step
# Epoch 25/100
# 16/16 - 0s - loss: 0.3178 - accuracy: 0.8402 - val_loss: 0.3515 - val_accuracy: 0.8595 - 461ms/epoch - 29ms/step
# Epoch 26/100
# 16/16 - 0s - loss: 0.3450 - accuracy: 0.8340 - val_loss: 0.3691 - val_accuracy: 0.8430 - 402ms/epoch - 25ms/step
# Epoch 27/100
# 16/16 - 0s - loss: 0.3581 - accuracy: 0.8361 - val_loss: 0.3693 - val_accuracy: 0.8182 - 383ms/epoch - 24ms/step
# Epoch 28/100
# 16/16 - 0s - loss: 0.3361 - accuracy: 0.8443 - val_loss: 0.3702 - val_accuracy: 0.8182 - 417ms/epoch - 26ms/step
# Epoch 29/100
# 16/16 - 0s - loss: 0.3101 - accuracy: 0.8463 - val_loss: 0.3539 - val_accuracy: 0.8430 - 425ms/epoch - 27ms/step
# Epoch 30/100
# 16/16 - 0s - loss: 0.3011 - accuracy: 0.8627 - val_loss: 0.3558 - val_accuracy: 0.8347 - 435ms/epoch - 27ms/step
# Epoch 31/100
# 16/16 - 0s - loss: 0.3243 - accuracy: 0.8422 - val_loss: 0.3548 - val_accuracy: 0.8512 - 389ms/epoch - 24ms/step
# Epoch 32/100
# 16/16 - 0s - loss: 0.3216 - accuracy: 0.8668 - val_loss: 0.3732 - val_accuracy: 0.8182 - 401ms/epoch - 25ms/step
# Epoch 33/100
# 16/16 - 0s - loss: 0.3062 - accuracy: 0.8545 - val_loss: 0.3529 - val_accuracy: 0.8512 - 373ms/epoch - 23ms/step
# Epoch 34/100
# 16/16 - 0s - loss: 0.3131 - accuracy: 0.8504 - val_loss: 0.3447 - val_accuracy: 0.8512 - 426ms/epoch - 27ms/step
# Epoch 35/100
# 16/16 - 0s - loss: 0.2891 - accuracy: 0.8586 - val_loss: 0.3286 - val_accuracy: 0.8760 - 420ms/epoch - 26ms/step
# Epoch 36/100
# 16/16 - 0s - loss: 0.2919 - accuracy: 0.8607 - val_loss: 0.3437 - val_accuracy: 0.8843 - 360ms/epoch - 23ms/step
# Epoch 37/100
# 16/16 - 0s - loss: 0.2826 - accuracy: 0.8648 - val_loss: 0.3448 - val_accuracy: 0.8512 - 359ms/epoch - 22ms/step
# Epoch 38/100
# 16/16 - 0s - loss: 0.3148 - accuracy: 0.8545 - val_loss: 0.3254 - val_accuracy: 0.8512 - 365ms/epoch - 23ms/step
# Epoch 39/100
# 16/16 - 0s - loss: 0.3276 - accuracy: 0.8381 - val_loss: 0.3099 - val_accuracy: 0.8760 - 387ms/epoch - 24ms/step
# Epoch 40/100
# 16/16 - 0s - loss: 0.2990 - accuracy: 0.8525 - val_loss: 0.3406 - val_accuracy: 0.8099 - 359ms/epoch - 22ms/step
# Epoch 41/100
# 16/16 - 0s - loss: 0.2832 - accuracy: 0.8607 - val_loss: 0.3255 - val_accuracy: 0.8512 - 361ms/epoch - 23ms/step
# Epoch 42/100
# 16/16 - 0s - loss: 0.2741 - accuracy: 0.8791 - val_loss: 0.3380 - val_accuracy: 0.8595 - 362ms/epoch - 23ms/step
# Epoch 43/100
# 16/16 - 0s - loss: 0.3092 - accuracy: 0.8484 - val_loss: 0.3311 - val_accuracy: 0.8430 - 371ms/epoch - 23ms/step
# Epoch 44/100
# 16/16 - 0s - loss: 0.2955 - accuracy: 0.8648 - val_loss: 0.3307 - val_accuracy: 0.8595 - 367ms/epoch - 23ms/step
# Epoch 45/100
# 16/16 - 0s - loss: 0.2676 - accuracy: 0.8689 - val_loss: 0.3383 - val_accuracy: 0.8264 - 368ms/epoch - 23ms/step
# Epoch 46/100
# 16/16 - 0s - loss: 0.2724 - accuracy: 0.8566 - val_loss: 0.3430 - val_accuracy: 0.8264 - 373ms/epoch - 23ms/step
# Epoch 47/100
# 16/16 - 0s - loss: 0.2650 - accuracy: 0.8832 - val_loss: 0.3504 - val_accuracy: 0.8430 - 357ms/epoch - 22ms/step
# Epoch 48/100
# 16/16 - 0s - loss: 0.2535 - accuracy: 0.8668 - val_loss: 0.3459 - val_accuracy: 0.8430 - 377ms/epoch - 24ms/step
# Epoch 49/100
# Restoring model weights from the end of the best epoch: 39.
# 16/16 - 0s - loss: 0.2922 - accuracy: 0.8996 - val_loss: 0.3357 - val_accuracy: 0.8430 - 405ms/epoch - 25ms/step
# Epoch 49: early stopping
# 4/4 [==============================] - 0s 5ms/step
#
# Mean accuracy: 0.8719, Standard deviation: 0.0082
#
# Mean recall: [0.96051052 0.55145889], Standard deviation: [0.0126565  0.04308528]
#
# Mean ROC AUC: 0.9124, Standard deviation: 0.0188

# %%
# Split the dataset into features (X) and target (y)
X = combined_df.drop(['hf_type', 'study_id', 'subject_id', 'sex', 'nrg_lin_scgk', 'nrg_rot_scgk', 'pwr_lin_scgk', 'pwr_rot_scgk', 'rsp'], axis=1)
y = combined_df['hf_type']

# Extract subject_id as groups
groups = combined_df['subject_id']

# Initialize the GroupShuffleSplit
gss = GroupShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

# Get the train and test indices based on the groups
train_idx, test_idx = next(gss.split(X, y, groups))

# Split the dataset into training and testing sets
X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

# Standardize the input features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# One-hot encode the target variable
encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(y_train)
y_test_enc = encoder.transform(y_test)
y_train_cat = to_categorical(y_train_enc)
y_test_cat = to_categorical(y_test_enc)

# Reshape the input features to fit the 1D CNN model
max_length = X_train.shape[1]
X_train = X_train.reshape((X_train.shape[0], max_length, 1))
X_test = X_test.reshape((X_test.shape[0], max_length, 1))

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dense, LSTM, Dropout, BatchNormalization, Add, Activation, GlobalAveragePooling1D, Multiply, Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

def se_block(input, channels, se_ratio=16):
    squeeze = GlobalAveragePooling1D()(input)
    excitation = Dense(channels // se_ratio, activation='relu')(squeeze)
    excitation = Dense(channels, activation='sigmoid')(excitation)
    return Multiply()([input, excitation])

def residual_block(input, filters, pool=False):
    x = Conv1D(filters, 3, padding='same')(input)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    if pool:
        x = MaxPooling1D(pool_size=2, strides=2)(x)  # Add this line
    x = Conv1D(filters, 3, padding='same')(x)
    x = BatchNormalization()(x)
    if pool:
        input = MaxPooling1D(pool_size=2, strides=2)(input)  # Add this line
    x = Add()([x, input])
    x = Activation('relu')(x)
    return x

def type1_residual_stage(input, filters):
    x = residual_block(input, filters, pool=True)
    x = residual_block(x, filters)
    x = residual_block(x, filters)
    x = se_block(x, filters)
    dense_connection = Conv1D(64, 1)(input)
    dense_connection = MaxPooling1D(pool_size=2, strides=2)(dense_connection)
    x = tf.keras.layers.concatenate([x, dense_connection], axis=-1)
    return x

def type2_residual_stage(input, filters):
    x = residual_block(input, filters)
    x = residual_block(x, filters)
    x = residual_block(x, filters)
    x = se_block(x, filters)
    return x



def create_model(input_shape):
    input = Input(shape=input_shape)

    x = Conv1D(32, 1)(input)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = se_block(x, 32)

    x = type1_residual_stage(x, 32)
    x = type2_residual_stage(x, 32)
    x = type1_residual_stage(x, 32)
    x = type2_residual_stage(x, 32)
    x = type1_residual_stage(x, 32)
    x = type2_residual_stage(x, 128)

    x = LSTM(32, return_sequences=True, go_backwards=False)(x)
    x = LSTM(32, return_sequences=False, go_backwards=True)(x)

    fc_layers = [64, 32, 16, 8]
    for units in fc_layers:
        x = Dense(units, activation='relu')(x)
        x = Dropout(0.15)(x)

    output = Dense(3, activation='softmax')(x)

    model = Model(inputs=input, outputs=output)
    model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

    return model

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import GroupShuffleSplit
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.utils import to_categorical


# Split the dataset into features (X) and target (y)
X = combined_df.drop(['hf_type', 'study_id', 'subject_id', 'sex', 'nrg_lin_scgk', 'nrg_rot_scgk', 'pwr_lin_scgk', 'pwr_rot_scgk', 'rsp'], axis=1)
y = combined_df['hf_type']

# Extract subject_id as groups
groups = combined_df['subject_id']

# Initialize the GroupShuffleSplit
gss = GroupShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

# Get the train and test indices based on the groups
train_idx, test_idx = next(gss.split(X, y, groups))

# Split the dataset into training and testing sets
X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

# Standardize the input features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# One-hot encode the target variable
encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(y_train)
y_test_enc = encoder.transform(y_test)
y_train_cat = to_categorical(y_train_enc)
y_test_cat = to_categorical(y_test_enc)

# Reshape the input features to fit the 1D CNN model
max_length = X_train.shape[1]
X_train = X_train.reshape((X_train.shape[0], max_length, 1))
X_test = X_test.reshape((X_test.shape[0], max_length, 1))

# Create the model
input_shape = (max_length, 1)
model = create_model(input_shape)
model.summary()

# Train the model
num_epochs = 100  # Adjust this value based on your needs
batch_size = 32   # Adjust this value based on your needs
model.fit(X_train, y_train_cat, epochs=num_epochs, batch_size=batch_size, validation_data=(X_test, y_test_cat))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [59], in <cell line: 44>()
#      42 # Create the model
#      43 input_shape = (max_length, 1)
# ---> 44 model = create_model(input_shape)
#      45 model.summary()
#      47 # Train the model
#
# Input In [58], in create_model(input_shape)
#      51 x = se_block(x, 32)
#      53 x = type1_residual_stage(x, 32)
# ---> 54 x = type2_residual_stage(x, 32)
#      55 x = type1_residual_stage(x, 32)
#      56 x = type2_residual_stage(x, 32)
#
# Input In [58], in type2_residual_stage(input, filters)
#      36 def type2_residual_stage(input, filters):
# ---> 37     x = residual_block(input, filters)
#      38     x = residual_block(x, filters)
#      39     x = residual_block(x, filters)
#
# Input In [58], in residual_block(input, filters, pool)
#      20 if pool:
#      21     input = MaxPooling1D(pool_size=2, strides=2)(input)  # Add this line
# ---> 22 x = Add()([x, input])
#      23 x = Activation('relu')(x)
#      24 return x
#
# File F:\conda\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File F:\conda\lib\site-packages\keras\layers\merging\base_merge.py:74, in _Merge._compute_elemwise_op_output_shape(self, shape1, shape2)
#      72     else:
#      73         if i != j:
# ---> 74             raise ValueError(
#      75                 "Inputs have incompatible shapes. "
#      76                 f"Received shapes {shape1} and {shape2}"
#      77             )
#      78         output_shape.append(i)
#      79 return tuple(output_shape)
#
# ValueError: Inputs have incompatible shapes. Received shapes (42, 32) and (42, 96)
